# %%
# %pip install nest_asyncio

import asyncio

import nest_asyncio


nest_asyncio.apply()

# %%
# from airflow.decorators import task
import requests
import json
import os
import asyncio
from aiohttp import ClientSession

import pandas as pd
import numpy as np
import itertools
from datetime import datetime
from typing import Tuple
loop = asyncio.ProactorEventLoop()
asyncio.set_event_loop(loop)

# %%
MAXIMUM_CONCURRENT_REQUESTS = 200

riot_tokens = [
    "RGAPI-d93ad850-d1e8-404a-a9f7-db6ba9a6016b", #PBE
    "RGAPI-58b977e3-1fe9-4eef-a1b9-8cf817e627fa", #NA
    "RGAPI-da3e753f-9145-4edc-8be5-54dce7e81e5c", #EUW
    "RGAPI-38d5ab33-910b-492e-ac00-bb5f086e03e8", #EUNE
    "RGAPI-07a5a53e-bbd1-44d2-9d5d-2c0f08b476d8", #MAIN
]
region_groupings = {
    "br1":"americas",
    "eun1":"europe",
    "euw1":"europe",
    "jp1":"asia",
    "kr":"asia",
    "la1":"americas",
    "la2":"americas",
    "na1":"americas",
    "oc1":"sea",
    "tr1":"europe",
    "ru":"europe",
    "ph2":"sea",
    "sg2":"sea",
    "th2":"sea",
    "tw2":"sea",
    "vn2":"sea",
}

# %%
start_date = datetime.now()
count = 0
rateLimitedCount = 0
async def api_request(url, riot_token: str, fromRateLimited = 0) -> dict:
    header = {
        "Accept-Language": "en-US,en;q=0.9",
        "Accept-Charset": "application/x-www-form-urlencoded; charset=UTF-8",
        "Origin": "https://developer.riotgames.com",
        "X-Riot-Token": riot_token,
    }
    async with ClientSession() as session:
        async with session.get(url, headers=header) as response:
            global rateLimitedCount
            global count 
            count+=1
            if fromRateLimited :
                rateLimitedCount -=1
                print(f"No longer Rate limited count: {rateLimitedCount}")

            print(f"Took {datetime.now() - start_date} to complete {count} requests on {url} and API token {riot_token}")
            if response.status == 429:
                retry_after = int(response.headers.get('Retry-After', '1'))
                print("Rate limited, retrying after " + str(retry_after) + " seconds.")

                rateLimitedCount +=1
                print("Rate limited count: " + str(rateLimitedCount))

                await asyncio.sleep(retry_after)
                return await api_request(url, riot_token,1)
            if response.status != 200:
                print(f"Error {response.status} on {url} with API {riot_token}")
            # assert response.status == 200
            return await response.json()

# %%
# @task(task_id="multiple_matches_ingest")
async def matches_request(matches: list[str]) -> list[dict]:
    requests_list = []
    for match in matches:
        print("Fetching match: " + match)
        region = region_groupings[match.split('_')[0].lower()]
        match_uri = f"https://{region}.api.riotgames.com/lol/match/v5/matches/{match}"
        requests_list.append(api_request(match_uri, np.random.choice(riot_tokens,1)[0]))

    semaphore = asyncio.Semaphore(MAXIMUM_CONCURRENT_REQUESTS)
    async def semaphored_request(request):
        async with semaphore:
            return await request
    return await asyncio.gather(*(semaphored_request(request) for request in requests_list))

async def players_matches_request(player_uuids : list[tuple], match_count : int ) -> list[dict]:
    requests_list = []
    for puuid, region_group, riot_token in player_uuids:
        request = api_request(f"https://{region_group}.api.riotgames.com/lol/match/v5/matches/by-puuid/{puuid}/ids?start=0&count={match_count}", riot_token)
        requests_list.append(request)

    semaphore = asyncio.Semaphore(MAXIMUM_CONCURRENT_REQUESTS)
    async def semaphored_request(request):
        async with semaphore:
            return await request
        
    return await asyncio.gather(*(semaphored_request(request) for request in requests_list))
    # return await asyncio.gather(*requests_list)
    
async def league_entries_request(queue: str, tier :str, division:str, page:int , region : str, riot_token : str) -> list[dict]:
    request = api_request(f"https://{region}.api.riotgames.com/lol/league-exp/v4/entries/{queue}/{tier}/{division}?page={page}", riot_token)
    return await asyncio.gather(*[request])

async def top_league_entries_request(queue : str, tier:str, region : str, riot_token : str) -> list[dict]:
    request = api_request(f"https://{region}.api.riotgames.com/lol/league/v4/{tier}/by-queue/{queue}", riot_token)
    return await asyncio.gather(*[request])

async def players_request(players : list[tuple]): #By SummonnerID -> "id" in JSON file
    requests_list = []

    for region, summonerID, riot_token in players:
        requests_list.append(api_request(f"https://{region}.api.riotgames.com/lol/summoner/v4/summoners/{summonerID}", str(riot_token)))
    
    semaphore = asyncio.Semaphore(MAXIMUM_CONCURRENT_REQUESTS)
    async def semaphored_request(request):
        async with semaphore:
            return await request
    
    # return await asyncio.gather(*requests_list)
    return await asyncio.gather(*(semaphored_request(request) for request in requests_list))

# %%
# @task(task_id="multiple_matches_ingest")
def matches_ingest(matches: list[str], limit = None) -> list[dict]:
    if limit is None:
        limit = len(matches)
    
    return asyncio.run(matches_request(itertools.islice(matches, 0, limit-1)))

# @task(task_id="players_matches_ingest")
def players_matches_ingest(player_uuids : list[tuple], match_count : int = 20) -> list[dict]:
    return asyncio.run(players_matches_request(player_uuids, match_count))
    
# @task(task_id="league_entries_ingest")
def league_entries_ingest(queue: str, tier :str, division:str, region, riot_token : str, page:int = 1) -> list[dict]:
    return asyncio.run(league_entries_request(queue, tier, division, page, region, riot_token))[0]

# @task(task_id="top_league_entries_ingest")
def top_league_entries_ingest(queue: str, tier:str,region, riot_token : str) -> dict:
    return asyncio.run(top_league_entries_request(queue, tier, region,riot_token))[0]

# @task(task_id="player_ingest")
def players_ingest(players : list[tuple]) -> list[dict]:
    return asyncio.run(players_request(players))

# %% [markdown]
# ### Clean DataFrame

# %%
# @task(task_id="clean_dataframe_dtypes")
def clean_dataframe_dtypes(df: pd.DataFrame, categorical_columns = [], int_columns = [], datetime_columns = []) -> pd.DataFrame:
    for column in categorical_columns:
        df[column] = df[column].astype("category")
    for column in int_columns:
        df[column] = df[column].astype("int")
    for column in datetime_columns:
        df[column] = pd.to_datetime(df[column])
    return df

# @task(task_id="reorder_coluns")
def reorder_columns(df: pd.DataFrame, ordered_columns: list[str]) -> pd.DataFrame:
    return df.reindex(columns=ordered_columns)

# @task(task_id="clean_dataframe")
def clean_dataframe(df: pd.DataFrame, categorical_columns = [], int_columns = [], datetime_columns = [], ordered_columns = []) -> pd.DataFrame:
    df = clean_dataframe_dtypes(df, categorical_columns, int_columns, datetime_columns)
    if len(ordered_columns) > 0:
        df = reorder_columns(df, ordered_columns)
    return df

# %% [markdown]
# ### Saving output to csv

# %%
# @task(task_id="save_to_csv")
def save_to_csv(df: pd.DataFrame, path: str, index: bool = False) -> None:
    """
        Note: Saving to CSV files are only temporary and will be removed after the entire piepline is completed.
    """
    if(os.path.exists(path)):
        df.to_csv(path, index=index, mode='a', header=False)
    else:
        df.to_csv(path, index=index, mode='w', header=True)

# %% [markdown]
# ### League Entries

# %%
#League Infos and Player League Infos is separated

# @task(task_id="top_league_entries")
def top_league_entries(queue: str, tier :str, region) -> Tuple[pd.DataFrame, pd.DataFrame]:
    riot_token : str = np.random.choice(riot_tokens)
    league_entries_raw : dict = top_league_entries_ingest(queue, tier, region, riot_token)

    if not league_entries_raw:
        return pd.DataFrame(), pd.DataFrame()
    
    current_time = datetime.now()

    player_league_infos = pd.DataFrame(league_entries_raw["entries"])
    player_league_infos["leagueId"] = league_entries_raw.get("leagueId")
    player_league_infos["last_updated"] = datetime.now()
    player_league_infos["riot_token"] = riot_token
    player_league_infos["region"] = region
    # player_league_infos = reorder_columns(player_league_infos, ordered_columns= ["leagueId","region","summonerId","summonerName","leaguePoints","rank","wins","losses","veteran","inactive","freshBlood","hotStreak","last_updated","riot_token"])

    del league_entries_raw["entries"]
    league_infos = pd.DataFrame([league_entries_raw])
    league_infos["last_updated"] = datetime.now()
    league_infos["queue"] = queue
    league_infos["region"] = region
    league_infos["division"] = 'I'
    league_infos["riot_token"] = riot_token
    # league_infos = reorder_columns(league_infos, ordered_columns= ["leagueId","region","queue","tier","division","name","last_updated","riot_token"])
    return league_infos, player_league_infos

# @task(task_id="league_entries")
def normal_league_entries(queue: str, tier :str, division:str, region : str, pages : int) -> Tuple[pd.DataFrame, pd.DataFrame]:
    player_leauge_infos_list = []
    league_infos_list = []
    for page in range(1, pages+1):
        riot_token : str = np.random.choice(riot_tokens)
     
        league_entries_raw : dict = pd.DataFrame.from_dict(league_entries_ingest(queue, tier, division, region, riot_token, page))

        if league_entries_raw.empty:
            return pd.DataFrame(), pd.DataFrame()

        player_league_infos = league_entries_raw.loc[:,['leagueId','summonerId','summonerName','leaguePoints','rank','wins','losses','veteran','inactive','freshBlood','hotStreak']]
        player_league_infos["last_updated"] = datetime.now()
        player_league_infos["riot_token"] = riot_token
        player_league_infos["region"] = region
        player_leauge_infos_list.append(player_league_infos)
        # player_league_infos = reorder_columns(player_league_infos,["leagueId","region","summonerId","summonerName","leaguePoints","rank","wins","losses","veteran","inactive","freshBlood","hotStreak","last_updated","riot_token"])

        league_infos = league_entries_raw.loc[:,['leagueId','tier']]
        league_infos["region"] = region
        league_infos["queue"] = queue
        league_infos["division"] = league_entries_raw["rank"]
        league_infos["last_updated"] = datetime.now()
        league_infos["riot_token"] = riot_token
        # league_infos = reorder_columns(league_infos, ordered_columns= ["leagueId","region","queue","tier","division","name","last_updated","riot_token"])
        league_infos.drop_duplicates(subset=["leagueId"], inplace=True)
        league_infos_list.append(league_infos)

    return pd.concat(league_infos_list, axis=0), pd.concat(player_leauge_infos_list,axis=0)

# @task(task_id="all_league_entries")
def league_entries(queue : str,
                   tier : str, 
                   division: str = None,
                   regions: list[str] = ["ph2", "eun1", "euw1", "jp1", "kr", "la1", "la2", "na1", "oc1", "ru", "sg2", "th2", "tr1", "tw2", "vn2","br1"],
                   pages : int = 1):
    """
        Main function for ingestion of data for leagues.
        Args:
            queue::str:
                The queue type of the league.  All valid values accepted according to API: RANK_FLEX_SR, RANK_FLEX_TT, RANKED_SOLO_5x5. Note that RANK_FLEX_TT is deprecated.
            tier::str:
                The league tier.  The following values are accepted: challengerleagues, grandmasterleagues, masterleagues, DIAMOND, PLATINUM, GOLD, SILVER, BRONZE, IRON
            division::str:
                The league division.  All valid values accepted according to API: I, II, III, IV.  Challenger to Master divisions only have one division.
            region::str:
                The region of the league. Default: All regions.  All valid values accepted according to API: ph2, eun1, euw1, jp1, kr, la1, la2, na1, oc1, ru, sg2, th2, tr1, tw2, vn2
            pages::int:
                The number of pages to be ingested.  Each page contains >20 entries and varies per region. Challenger to Master divisions always show the complete list (only 1 page).  
        Returns:
            None
    """
    league_infos_list = []
    if tier in ["challengerleagues", "grandmasterleagues", "masterleagues"]:
        league_infos_list = [top_league_entries(queue=queue, tier=tier, region=region) for region in regions]
    else:
        if division is None:
            raise ValueError("Division must be specified for non-Challenger to Master divisions.")
        league_infos_list = [normal_league_entries(queue=queue, tier=tier, division=division, region=region, pages=pages) for region in regions]

    league_infos_list = list(zip(*league_infos_list))
    return pd.concat(league_infos_list[0],axis=0), pd.concat(league_infos_list[1],axis=0)

# %% [markdown]
# ### Player Details

# %%
league_info, player_league_info = league_entries(queue="RANKED_SOLO_5x5", tier="challengerleagues", division='I', pages=1)
player_ids = list(player_league_info[["region","summonerId","riot_token"]].itertuples(index=False, name=None))
player_info = players_ingest(player_ids)
# Out:
# Took 0:00:38.749173 to complete 2 requests on https://ph2.api.riotgames.com/lol/league/v4/challengerleagues/by-queue/RANKED_SOLO_5x5 and API token RGAPI-d93ad850-d1e8-404a-a9f7-db6ba9a6016b
# Error 403 on https://ph2.api.riotgames.com/lol/league/v4/challengerleagues/by-queue/RANKED_SOLO_5x5 with API RGAPI-d93ad850-d1e8-404a-a9f7-db6ba9a6016b
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# d:\Educational Others\2023 Data Engineering Zoomcamp Project\flows\api_ingestion\api_ingest.ipynb Cell 14 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/d%3A/Educational%20Others/2023%20Data%20Engineering%20Zoomcamp%20Project/flows/api_ingestion/api_ingest.ipynb#X16sZmlsZQ%3D%3D?line=0'>1</a> league_info, player_league_info = league_entries(queue="RANKED_SOLO_5x5", tier="challengerleagues", division='I', pages=1)
#       <a href='vscode-notebook-cell:/d%3A/Educational%20Others/2023%20Data%20Engineering%20Zoomcamp%20Project/flows/api_ingestion/api_ingest.ipynb#X16sZmlsZQ%3D%3D?line=1'>2</a> player_ids = list(player_league_info[["region","summonerId","riot_token"]].itertuples(index=False, name=None))
#       <a href='vscode-notebook-cell:/d%3A/Educational%20Others/2023%20Data%20Engineering%20Zoomcamp%20Project/flows/api_ingestion/api_ingest.ipynb#X16sZmlsZQ%3D%3D?line=2'>3</a> player_info = players_ingest(player_ids)
#
# d:\Educational Others\2023 Data Engineering Zoomcamp Project\flows\api_ingestion\api_ingest.ipynb Cell 14 in league_entries(queue, tier, division, regions, pages)
#      <a href='vscode-notebook-cell:/d%3A/Educational%20Others/2023%20Data%20Engineering%20Zoomcamp%20Project/flows/api_ingestion/api_ingest.ipynb#X16sZmlsZQ%3D%3D?line=82'>83</a> league_infos_list = []
#      <a href='vscode-notebook-cell:/d%3A/Educational%20Others/2023%20Data%20Engineering%20Zoomcamp%20Project/flows/api_ingestion/api_ingest.ipynb#X16sZmlsZQ%3D%3D?line=83'>84</a> if tier in ["challengerleagues", "grandmasterleagues", "masterleagues"]:
# ---> <a href='vscode-notebook-cell:/d%3A/Educational%20Others/2023%20Data%20Engineering%20Zoomcamp%20Project/flows/api_ingestion/api_ingest.ipynb#X16sZmlsZQ%3D%3D?line=84'>85</a>     league_infos_list = [top_league_entries(queue=queue, tier=tier, region=region) for region in regions]
#      <a href='vscode-notebook-cell:/d%3A/Educational%20Others/2023%20Data%20Engineering%20Zoomcamp%20Project/flows/api_ingestion/api_ingest.ipynb#X16sZmlsZQ%3D%3D?line=85'>86</a> else:
#      <a href='vscode-notebook-cell:/d%3A/Educational%20Others/2023%20Data%20Engineering%20Zoomcamp%20Project/flows/api_ingestion/api_ingest.ipynb#X16sZmlsZQ%3D%3D?line=86'>87</a>     if division is None:
#
# d:\Educational Others\2023 Data Engineering Zoomcamp Project\flows\api_ingestion\api_ingest.ipynb Cell 14 in <listcomp>(.0)
#      <a href='vscode-notebook-cell:/d%3A/Educational%20Others/2023%20Data%20Engineering%20Zoomcamp%20Project/flows/api_ingestion/api_ingest.ipynb#X16sZmlsZQ%3D%3D?line=82'>83</a> league_infos_list = []
#      <a href='vscode-notebook-cell:/d%3A/Educational%20Others/2023%20Data%20Engineering%20Zoomcamp%20Project/flows/api_ingestion/api_ingest.ipynb#X16sZmlsZQ%3D%3D?line=83'>84</a> if tier in ["challengerleagues", "grandmasterleagues", "masterleagues"]:
# ---> <a href='vscode-notebook-cell:/d%3A/Educational%20Others/2023%20Data%20Engineering%20Zoomcamp%20Project/flows/api_ingestion/api_ingest.ipynb#X16sZmlsZQ%3D%3D?line=84'>85</a>     league_infos_list = [top_league_entries(queue=queue, tier=tier, region=region) for region in regions]
#      <a href='vscode-notebook-cell:/d%3A/Educational%20Others/2023%20Data%20Engineering%20Zoomcamp%20Project/flows/api_ingestion/api_ingest.ipynb#X16sZmlsZQ%3D%3D?line=85'>86</a> else:
#      <a href='vscode-notebook-cell:/d%3A/Educational%20Others/2023%20Data%20Engineering%20Zoomcamp%20Project/flows/api_ingestion/api_ingest.ipynb#X16sZmlsZQ%3D%3D?line=86'>87</a>     if division is None:
#
# d:\Educational Others\2023 Data Engineering Zoomcamp Project\flows\api_ingestion\api_ingest.ipynb Cell 14 in top_league_entries(queue, tier, region)
#       <a href='vscode-notebook-cell:/d%3A/Educational%20Others/2023%20Data%20Engineering%20Zoomcamp%20Project/flows/api_ingestion/api_ingest.ipynb#X16sZmlsZQ%3D%3D?line=8'>9</a>     return pd.DataFrame(), pd.DataFrame()
#      <a href='vscode-notebook-cell:/d%3A/Educational%20Others/2023%20Data%20Engineering%20Zoomcamp%20Project/flows/api_ingestion/api_ingest.ipynb#X16sZmlsZQ%3D%3D?line=10'>11</a> current_time = datetime.now()
# ---> <a href='vscode-notebook-cell:/d%3A/Educational%20Others/2023%20Data%20Engineering%20Zoomcamp%20Project/flows/api_ingestion/api_ingest.ipynb#X16sZmlsZQ%3D%3D?line=12'>13</a> player_league_infos = pd.DataFrame(league_entries_raw["entries"])
#      <a href='vscode-notebook-cell:/d%3A/Educational%20Others/2023%20Data%20Engineering%20Zoomcamp%20Project/flows/api_ingestion/api_ingest.ipynb#X16sZmlsZQ%3D%3D?line=13'>14</a> player_league_infos["leagueId"] = league_entries_raw.get("leagueId")
#      <a href='vscode-notebook-cell:/d%3A/Educational%20Others/2023%20Data%20Engineering%20Zoomcamp%20Project/flows/api_ingestion/api_ingest.ipynb#X16sZmlsZQ%3D%3D?line=14'>15</a> player_league_infos["last_updated"] = datetime.now()
#
# KeyError: 'entries'

# %%
accounts_raw = pd.DataFrame(player_info).merge(player_league_info, left_on='id', right_on = 'summonerId', how='right')

accounts_raw["region_group"] = accounts_raw["region"].map(region_groupings)
assert accounts_raw["region_group"].isna().sum() == 0

# display(accounts_raw["region"].unique())
match_history_raw = players_matches_ingest(list(accounts_raw[['puuid','region_group','riot_token']].itertuples(index=False, name=None)))
# Out:
# Took 0:33:17.162338 to complete 15403 requests on https://sea.api.riotgames.com/lol/match/v5/matches/by-puuid/9yLQPygucQUizvWGrHIGOTJQEdqIwELggpXo9c1kyDdRPqge31MBjaLzBdjCThG-71_YA_CUk0eMzw/ids?start=0&count=20 and API token RGAPI-d93ad850-d1e8-404a-a9f7-db6ba9a6016b
# Rate limited, retrying after 2 seconds.
# Rate limited count: 11
# Took 0:33:17.176323 to complete 15404 requests on https://sea.api.riotgames.com/lol/match/v5/matches/by-puuid/3LkIfyIhZP1_g57-8iDKjRRo3zhcB-ZW-178uBsez9XJUog5FWK2oXdfRCyeL3SC1_u_-KxohOFiCw/ids?start=0&count=20 and API token RGAPI-d93ad850-d1e8-404a-a9f7-db6ba9a6016b
# Rate limited, retrying after 2 seconds.
# Rate limited count: 12
# Took 0:33:17.183480 to complete 15405 requests on https://sea.api.riotgames.com/lol/match/v5/matches/by-puuid/UQpGAuaGvo2k8AQdVoIX9CKn7sKJzG60cVYzqE-0huisuGM_ZpK-y25lEhVziLTqL2lvnqXByrXTsA/ids?start=0&count=20 and API token RGAPI-d93ad850-d1e8-404a-a9f7-db6ba9a6016b
# Rate limited, retrying after 2 seconds.
# Rate limited count: 13
# Took 0:33:17.220327 to complete 15406 requests on https://sea.api.riotgames.com/lol/match/v5/matches/by-puuid/tOso7z0eGVBIZot8rcYLi2HiGuwkzBXzHsnOtakTfB1fBE72Z68gFVKFtQbrb325fAXNRxLR3WYgZw/ids?start=0&count=20 and API token RGAPI-d93ad850-d1e8-404a-a9f7-db6ba9a6016b
# Rate limited, retrying after 2 seconds.
# Rate limited count: 14
# Took 0:33:17.223442 to complete 15407 requests on https://sea.api.riotgames.com/lol/match/v5/matches/by-puuid/WtXmSBOEDJYH768fv8idrzzvMw7wAXy1wMZR_1C3KxbXfyyb_JpSPDGsPuoGyyXoiYN-DFcTE36A7w/ids?start=0&count=20 and API token RGAPI-d93ad850-d1e8-404a-a9f7-db6ba9a6016b
# Took 0:33:17.224364 to complete 15408 requests on https://sea.api.riotgames.com/lol/match/v5/matches/by-puuid/gUD74arJwDtqxYpAbjh9eVDpxAeWiFxFsiAiP7VP68DlIGPyBSyUZGugUUdyYgDUyksAsMLU0ux_Rg/ids?start=0&count=20 and API token RGAPI-d93ad850-d1e8-404a-a9f7-db6ba9a6016b
# Took 0:33:17.224364 to complete 15409 requests on https://sea.api.riotgames.com/lol/match/v5/matches/by-puuid/1RIrtrYavDrl45I7wFVEfgRylOi8hleEMAGsTKG-r2M3P9gt_PVI3XdcsfJ7Vf4HQEM-8-Qn5eKMGA/ids?start=0&count=20 and API token RGAPI-d93ad850-d1e8-404a-a9f7-db6ba9a6016b
# Rate limited, retrying after 2 seconds.
# Rate limited count: 15
# Took 0:33:17.224364 to complete 15410 requests on https://sea.api.riotgames.com/lol/match/v5/matches/by-puuid/Rw72m94AU2eaFBKzXnrosKSE75nR0ttW0i5cEFg0WcT9Y_T_o3giyYW-fJ9eiN0Xi-S6k9zw5-NZMg/ids?start=0&count=20 and API token RGAPI-d93ad850-d1e8-404a-a9f7-db6ba9a6016b
# Rate limited, retrying after 2 seconds.
# Rate limited count: 16
# Took 0:33:17.224364 to complete 15411 requests on https://sea.api.riotgames.com/lol/match/v5/matches/by-puuid/7HzhKdNWLzUFoCfPudpaxmS5sYuWtQl1Px0tIEdYw4aNfIaBevfGtI3MkS23b2oWUAqgFLFJx6HrvA/ids?start=0&count=20 and API token RGAPI-d93ad850-d1e8-404a-a9f7-db6ba9a6016b
# Rate limited, retrying after 2 seconds.
# Rate limited count: 17
# Took 0:33:17.224364 to complete 15412 requests on https://sea.api.riotgames.com/lol/match/v5/matches/by-puuid/_dKOkEQBIcMTFWe886zZXdszEaxiL3xzwu2L3ehmJH2sRv7UfKdIvWm0i2X12qmdbjIT3BUxxWECgw/ids?start=0&count=20 and API token RGAPI-d93ad850-d1e8-404a-a9f7-db6ba9a6016b
# Rate limited, retrying after 2 seconds.
# Rate limited count: 18
# Took 0:33:17.224364 to complete 15413 requests on https://sea.api.riotgames.com/lol/match/v5/matches/by-puuid/JFSf2VX1WH_9trk0RR334GTZir8jJkIQq-L_f-AAznH76i328ZLnzkj7zIYFhODQGuG_4PtXZGGdTA/ids?start=0&count=20 and API token RGAPI-d93ad850-d1e8-404a-a9f7-db6ba9a6016b
# Rate limited, retrying after 2 seconds.
# Rate limited count: 19
# Took 0:33:17.225324 to complete 15414 requests on https://sea.api.riotgames.com/lol/match/v5/matches/by-puuid
requests on https://americas.api.riotgames.com/lol/match/v5/matches/by-puuid/RUY8sXGuZpj9ui9cpd0IL2HLEEKdXUziSdc_ncqP4a8Gc4X5hnWSyR2HqEikcPpQg8hUfhUqbWJoQA/ids?start=0&count=20 and API token RGAPI-d93ad850-d1e8-404a-a9f7-db6ba9a6016b
# No longer Rate limited count: 19
# Took 0:49:57.988444 to complete 22189 requests on https://americas.api.riotgames.com/lol/match/v5/matches/by-puuid/7EIIhm8EjkNjPuUtc90heLpvY-n2nIrI2CPDsWNn8KMnsILfGnf_K7LjFQGa9PdR4ZC3Xit6nYMUxw/ids?start=0&count=20 and API token RGAPI-d93ad850-d1e8-404a-a9f7-db6ba9a6016b
# No longer Rate limited count: 18
# Took 0:49:58.015184 to complete 22190 requests on https://americas.api.riotgames.com/lol/match/v5/matches/by-puuid/OhsbHB1-STFqxy3R0XIf-G8XmRcLCzpFyYRS_TWEbxRhma1udsZPbH1jizoCGgn-5mxkzoUFUNSKuw/ids?start=0&count=20 and API token RGAPI-d93ad850-d1e8-404a-a9f7-db6ba9a6016b
# No longer Rate limited count: 17
# Took 0:49:58.288992 to complete 22191 requests on https://americas.api.riotgames.com/lol/match/v5/matches/by-puuid/KfsiPOyo6AYyLM3m-8werhBTGuM7IHwzrgSIlrjqcx_SKMz1z1FkFCIVi-W7Q95GpmatN4Q4AuB9Cw/ids?start=0&count=20 and API token RGAPI-d93ad850-d1e8-404a-a9f7-db6ba9a6016b
# No longer Rate limited count: 16
# Took 0:49:58.288992 to complete 22192 requests on https://americas.api.riotgames.com/lol/match/v5/matches/by-puuid/aAAoi2hU9IGYD93HlC0g6lannml2VWKuwjIRZkwG8NW-ttVWCRArkv2k-q4wxSj62nm-msWxag0arg/ids?start=0&count=20 and API token RGAPI-d93ad850-d1e8-404a-a9f7-db6ba9a6016b
# No longer Rate limited count: 15
# Took 0:49:58.316465 to complete 22193 requests on https://americas.api.riotgames.com/lol/match/v5/matches/by-puuid/DD_t83yvJ7b6y_HQcRZdG-0rB81c78YmbEXz2jRn-7xqrOe3TAxRiJm_FpE5xGbQZ89ROD0AWyHarw/ids?start=0&count=20 and API token RGAPI-d93ad850-d1e8-404a-a9f7-db6ba9a6016b
# No longer Rate limited count: 14
# Took 0:49:58.330456 to complete 22194 requests on https://americas.api.riotgames.com/lol/match/v5/matches/by-puuid/DwmEgecUANMsjN-7IpiXgZRJuyr-n4mpEXYBZAOIrLXIK62fdIDdgfP6htUavJN5mI8mqh5OHIHDfg/ids?start=0&count=20 and API token RGAPI-d93ad850-d1e8-404a-a9f7-db6ba9a6016b
# No longer Rate limited count: 13
# Took 0:49:58.440435 to complete 22195 requests on https://americas.api.riotgames.com/lol/match/v5/matches/by-puuid/RpQybn8e19S8RGMRcafQSYviDC-JO4NDtmjKPPoJzgZziqSlgqqr0NanCjWqzl4cTlC7qXKR5zqOJA/ids?start=0&count=20 and API token RGAPI-d93ad850-d1e8-404a-a9f7-db6ba9a6016b
# No longer Rate limited count: 12
# Took 0:50:00.750277 to complete 22196 requests on https://americas.api.riotgames.com/lol/match/v5/matches/by-puuid/VKFrw3npJOQRVXBGguCfx7omQwTGV4DUkYY6PYxyqCAVm89X989QZBpRmCskV9SrABfou2Dp4Iy_Hw/ids?start=0&count=20 and API token RGAPI-d93ad850-d1e8-404a-a9f7-db6ba9a6016b
# No longer Rate limited count: 11
# Took 0:50:04.800315 to complete 22197 requests on https://americas.api.riotgames.com/lol/match/v5/matches/by-puuid/rLX0X5tgL4YbFnx3f-zQvzpP39KY9fgnkmkvjWZCENYRM2NJ_IS3mGOHBcZ4irBwTf6D8VqAZhK3Kw/ids?start=0&count=20 and API token RGAPI-d93ad850-d1e8-404a-a9f7-db6ba9a6016b
# No longer Rate limited count: 10
# Took 0:50:05.128420 to complete 22198 requests on https://americas.api.riotgames.com/lol/match/v5/matches/by-puuid/tJg_ixPM1MFlS5U6DlMMmkINrjE6qFUA2bXJK7GiHJs_bOtoI6QJJBSywQeUSJbFoNcOA2uP_fn8gg/ids?start=0&count=20 and API token RGAPI-d93ad850-d1e8-404a-a9f7-db6ba9a6016b

# %%
match_history_list = set(itertools.chain.from_iterable(match_history_raw))
raw_match_history_details = matches_ingest(match_history_list, 3000)
# Out:
# Fetching match: RU_435038708
# Fetching match: NA1_4602846851
# Fetching match: LA2_1280731187
# Fetching match: LA2_1278214825
# Fetching match: EUW1_6328908072
# Fetching match: EUN1_3334438846
# Fetching match: TR1_1390568793
# Fetching match: BR1_2698384332
# Fetching match: VN2_53993533
# Fetching match: NA1_4608264757
# Fetching match: TR1_1392075600
# Fetching match: VN2_53999277
# Fetching match: BR1_2690624675
# Fetching match: EUN1_3334984119
# Fetching match: PH2_8245658
# Fetching match: EUW1_6313690293
# Fetching match: BR1_2700970157
# Fetching match: BR1_2700839663
# Fetching match: JP1_390433512
# Fetching match: EUN1_3335595354
# Fetching match: LA2_1276408333
# Fetching match: LA1_1369760092
# Fetching match: NA1_4595820748
# Fetching match: LA2_1280388589
# Fetching match: VN2_53343253
# Fetching match: TR1_1391759686
# Fetching match: PH2_7950648
# Fetching match: KR_6416394663
# Fetching match: KR_6418924237
# Fetching match: LA1_1369570135
# Fetching match: KR_6413974868
# Fetching match: EUN1_3336947456
# Fetching match: NA1_4604868557
# Fetching match: NA1_4603365074
# Fetching match: TH2_3567991
# Fetching match: EUN1_3335529573
# Fetching match: LA1_1369916024
# Fetching match: VN2_54179578
# Fetching match: LA2_1280830016
# Fetching match: NA1_4604618039
# Fetching match: OC1_563603366
# Fetching match: KR_6414340738
# Fetching match: LA1_1368955703
# Fetching match: EUN1_3335283255
# Fetching match: NA1_4609357780
# Fetching match: NA1_4609270136
# Fetching match: VN2_51312900
# Fetching match: JP1_390764153
# Fetching match: TR1_1392097481
# Fetching match: LA1_1368438294
# Fetching match: TW2_48064578
# Fetching match: TW2_48858020
# Fetching match: NA1_4607794485
# Fetching match: PH2_7579856
# Fetching match: PH2_8381915
# Fetching match: EUN1_3337730002
# Fetching match: VN2_53344670
# Fetching match: VN2_54172430
# Fetching match: TR1_1391313337
# Fetching match: BR1_2698642280
# Fetching match: LA2_1276353295
# Fetching match: TR1_1390951596
# Fetching match: VN2_46054350
# Fetching match: EUW1_6325840993
# Fetching match: JP1_390992456
# Fetching match: TR1_1392041980
# Fetching match: BR1_2700177827
# Fetching match: LA1_1369274341
# Fetching match: BR1_2696732020
# Fetching match: BR1_2699509703
# Fetching match: EUN1_3335027557
# Fetching match: SG2_4596348
# Fetching match: RU_435153257
# Fetching match: VN2_45880448
# Fetching match: TW2_48970925
# Fetching match: PH2_8368625
# Fetching match: EUW1_6328979312
# Fetching match: TH2_3500094
# Fetching match: EUW1_6329084423
# Fetching match: OC1_563808642
# Fetching match: PH2_7738473
# Fetching match: LA1_1369126811
# Fetching match: NA1_4608772863
# Fetching match: NA1_4592232920
# Fetching match: VN2_52942565
# Fetching match: EUN1_3335520083
# Fetching match: LA2_1279867209
# Fetching match: NA1_4606348500
# Fetching match: RU_434405793
# Fetching match: TR1_1391746578
# Fetching match: VN2_51393017
# Fetching match: PH2_7920817
# Fetching match: NA1_4607941315
# Fetching match: SG2_4421711
# Fetching match: EUW1_6324700985
# Fetching match: TR1_1392461523
# Fetching match: TR1_1390394225
# Fetching match: EUN1_3335063783
# Fetching match: NA1_4603970979
# Fetching match: PH2_8318149
# Fetching match: NA1_4600554128
# Fetching match: VN2_48723009
# Fetching match: NA1_4608824484
# Fetching match: NA1_4608922208
# Fetching match: TR1_1390842260
# Fetching match: RU_434820713
# Fetching match: VN2_52193832
# Fetching match: BR1_2699949187
# Fetching match: NA1_4596603825
# Fetching match: PH2_8506151
# Fetching match: KR_6414164457
# Fetching match: TW2_48823784
# Fetching match: KR_6413527289
# Fetching match: NA1_4602733046
# Fetching match: PH2_7524491
# Fetching match: LA1_1369233820
# Fetching match: TW2_46648746
# Fetching match: EUN1_3329195355
# Fetching match: TH2_3456037
# Fetching match: EUN1_3337854899
# Fetching match: NA1_4608204653
# Fetching match: NA1_4607910007
# Fetching match: BR1_2693052502
# Fetching match: PH2_7088186
# Fetching match: BR1_2701005916
# Fetching match: EUW1_6327294886
# Fetching match: TW2_48812199
# Fetching match: VN2_50813118
# Fetching match: TW2_46321590
# Fetching match: KR_6416380232
# Fetching match: LA2_1280417188
# Fetching match: PH2_7495040
# Fetching match: LA1_1369641557
# Fetching match: PH2_7704857
# Fetching match: TW2_46436285
# Fetching match: VN2_53924426
# Fetching match: LA1_1369300840
# Fetching match: EUN1_3336809771
# Fetching match: BR1_2693206626
# Fetching match: OC1_562675606
# Fetching match: EUN1_3338131810
# Fetching match: NA1_4609713960
# Fetching match: NA1_4607855278
# Fetching match: EUW1_6326738780
# Fetching match: TR1_1390706227
# Fetching match: EUN1_3336831896
# Fetching match: BR1_2700431687
# Fetching match: LA1_1369597121
# Fetching match: NA1_4608431662
# Fetching match: LA2_1279940521
# Fetching match: VN2_50885644
# Fetching match: NA1_4602979330
# Fetching match: KR_6415593271
# Fetching match: TW2_46082164
# Fetching match: EUW1_6325735022
# Fetching match: BR1_2698254445
# Fetching match: EUN1_3333936679
# Fetching match: TW2_46648878
# Fetching match: LA1_1367778634
# Fetching match: NA1_4605929145
# Fetching match: KR_6418476414
# Fetching match: PH2_8049870
# Fetching match: TH2_3529562
# Fetching match: VN2_53532119
# Fetching match: KR_6414786873
# Fetching match: NA1_4605570663
# Fetching match: VN2_51832345
# Fetching match: NA1_4597919353
# Fetching match: VN2_43645131
# Fetching match: LA1_1369779700
# Fetching match: EUW1_6320913653
# Fetching match: NA1_4607703460
# Fetching match: TW2_47480220
# Fetching match: EUN1_3338008033
# Fetching match: KR_6417228792
# Fetching match: KR_6413074379
# Fetching match: NA1_4609735994
# Fetching match: NA1_4610054806
# Fetching match: TR1_1392070603
# Fetching match: TR1_1390828053
# Fetching match: TW2_46463187
# Fetching match: NA1_4605278265
# Fetching match: EUN1_3335029948
# Fetching match: PH2_7091529
# Fetching match: PH2_6992479
# Fetching match: VN2_52777919
# Fetching match: EUW1_6326020269
# Fetching match: TR1_1391515751
# Fetching match: PH2_8410825
# Fetching match: BR1_2699075401
# Fetching match: PH2_7609056
# Fetching match: EUN1_3338465240
# Fetching match: NA1_4607885496
# Fetching match: LA1_1369651063
# Fetching match: LA2_1280233707
# Fetching match: TH2_3224134
# Fetching match: KR_6413446411
# Fetching match: LA2_1279417512
# Fetching match: NA1_4603823397
# Fetching match: EUW1_6325590322
# Fetching match: EUW1_6315707359
# Fetching match: LA1_1368445938
# Fetching match: EUW1_6316648693
# Fetching match: VN2_50638722
# Fetching match: LA2_1280654266
# Fetching match: TR1_1392043386
# Fetching match: VN2_51059665
# Fetching match: EUW1_6328879832
# Fetching match: SG2_4909452
# Fetching match: LA1_1369784885
# Fetching match: VN2_49912971
# Fetching match: TW2_45525489
# Fetching match: TW2_46878171
# Fetching match: EUN1_3336973082
# Fetching match: EUN1_3329963653
# Fetching match: PH2_8523771
# Fetching match: NA1_4604499759
# Fetching match: KR_6415512151
# Fetching match: LA2_1280683470
# Fetching match: PH2_8494969
# Fetching match: VN2_52209812
# Fetching match: NA1_4603853220
# Fetching match: TR1_1392074219
# Fetching match: VN2_50308028
# Fetching match: BR1_2700212626
# Fetching match: LA1_1369559467
# Fetching match: LA1_1367975230
# Fetching match: TR1_1392487436
# Fetching match: TR1_1392427057
# Fetching match: NA1_4603706836
# Fetching match: BR1_2701212955
# Fetching match: LA1_1368242689
# Fetching match: TR1_1391804614
# Fetching match: TH2_3462373
# Fetching match: TR1_1392409462
# Fetching match: EUW1_6326010048
# Fetching match: EUW1_6329326344
# Fetching match: RU_432988235
# Fetching match: LA1_1368400693
# Fetching match: LA1_1369713659
# Fetching match: NA1_4607449455
# Fetching match: LA1_1369048388
# Fetching match: EUW1_6326363657
# Fetching match: VN2_52188580
# Fetching match: EUW1_6325758979
# Fetching match: TR1_1392414981
# Fetching match: BR1_2700814564
# Fetching match: BR1_2697155138
# Fetching match: KR_6400544388
# Fetching match: TR1_1392060688
# Fetching match: EUW1_6329377959
# Fetching match: BR1_2700614630
# Fetching match: TW2_45538996
# Fetching match: LA2_1279107367
# Fetching match: TW2_47046231
# Fetching match: TH2_3431293
# Fetching match: TR1_1391837366
# Fetching match: SG2_4300811
# Fetching match: TW2_48683406
# Fetching match: LA2_1278835367
# Fetching match: TR1_1392049853
# Fetching match: TW2_46771308
# Fetching match: EUN1_3335988954
# Fetching match: TW2_47221011
# Fetching match: VN2_54191802
# Fetching match: RU_434899760
# Fetching match: EUN1_3337827009
# Fetching match: PH2_7745573
# Fetching match: NA1_4607228848
# Fetching match: BR1_2699874043
# Fetching match: BR1_2692498867
# Fetching match: LA2_1280407997
# Fetching match: PH2_7421611
# Fetching match: KR_6416440250
# Fetching match: PH2_7750122
# Fetching match: LA2_1280927250
# Fetching match: VN2_50899361
# Fetching match: TW2_47386554
# Fetching match: PH2_8185726
# Fetching match: VN2_49468290
# Fetching match: KR_6419200349
# Fetching match: TW2_48945605
# Fetching match: LA1_1369545609
# Fetching match: EUN1_3337004873
# Fetching match: TR1_1390640601
# Fetching match: TR1_1390886488
# Fetching match: LA2_1280425747
# Fetching match: EUN1_3338169016
# Fetching match: LA1_1367432622
# Fetching match: RU_435101192
# Fetching match: LA1_1367645934
# Fetching match: TR1_1388549838
# Fetching match: EUN1_3333516622
# Fetching match: PH2_8103721
# Fetching match: LA1_1367314775
# Fetching match: BR1_2699754894
# Fetching match: PH2_8235363
# Fetching match: EUW1_6324410223
# Fetching match: TW2_46131723
# Fetching match: EUW1_6326192062
# Fetching match: TR1_1391027959
# Fetching match: EUN1_3333728400
# Fetching match: LA1_1369643418
# Fetching match: TR1_1391525029
# Fetching match: VN2_53126542
# Fetching match: TW2_47350146
# Fetching match: KR_6402405741
# Fetching match: LA2_1279184811
# Fetching match: TW2_46343843
# Fetching match: TR1_1392464017
# Fetching match: TR1_1391519934
# Fetching match: JP1_390226399
# Fetching match: RU_434452711
# Fetching match: EUW1_6315061352
# Fetching match: TR1_1391927872
# Fetching match: EUW1_6321378616
# Fetching match: PH2_7185866
# Fetching match: NA1_4606357784
# Fetching match: PH2_8145437
# Fetching match: SG2_4595128
# Fetching match: NA1_4603678777
# Fetching match: LA1_1367039497
# Fetching match: LA1_1364255746
# Fetching match: LA1_1368604418
# Fetching match: EUN1_3338025510
# Fetching match: PH2_7707268
# Fetching match: KR_6416643579
# Fetching match: LA2_1280124535
# Fetching match: BR1_2695756160
# Fetching match: BR1_2700810385
# Fetching match: TR1_1392374266
# Fetching match: PH2_8525553
# Fetching match: LA2_1280651394
# Fetching match: SG2_4856460
# Fetching match: PH2_7828147
# Fetching match: BR1_2700307596
# Fetching match: TW2_47379393
# Fetching match: LA2_1280144715
# Fetching match: BR1_2699610220
# Fetching match: NA1_4598696175
# Fetching match: KR_6406941855
# Fetching match: OC1_563117533
# Fetching match: TW2_45414269
# Fetching match: EUW1_6326289358
# Fetching match: LA1_1368508415
# Fetching match: TH2_3348461
# Fetching match: NA1_4606197358
# Fetching match: LA1_1369849361
# Fetching match: TW2_48315058
# Fetching match: VN2_51641332
# Fetching match: BR1_2697914207
# Fetching match: NA1_4607462143
# Fetching match: KR_6414719758
# Fetching match: VN2_54196064
# Fetching match: LA2_1279513463
# Fetching match: RU_435111735
# Fetching match: NA1_4599453261
# Fetching match: SG2_4602900
# Fetching match: KR_6400700969
# Fetching match: NA1_4601250005
# Fetching match: PH2_8471887
# Fetching match: EUW1_6306751988
# Fetching match: RU_434547587
# Fetching match: PH2_8460692
# Fetching match: LA1_1369094177
# Fetching match: TR1_1390821040
# Fetching match: LA2_1279943509
# Fetching match: NA1_4610028732
# Fetching match: TW2_49010660
# Fetching match: TW2_44224233
# Fetching match: KR_6415572216
# Fetching match: PH2_8431724
# Fetching match: EUW1_6318762871
# Fetching match: LA1_1365464010
# Fetching match: LA2_1280547868
# Fetching match: NA1_4604602269
# Fetching match: KR_6418418414
# Fetching match: KR_6413117181
# Fetching match: KR_6405611086
# Fetching match: KR_6415731592
# Fetching match: SG2_4783877
# Fetching match: VN2_38979094
# Fetching match: TR1_1392356266
# Fetching match: NA1_4605297756
# Fetching match: TW2_47633514
# Fetching match: TW2_45675790
# Fetching match: LA1_1368038763
# Fetching match: BR1_2698257028
# Fetching match: NA1_4609974454
# Fetching match: NA1_4608550270
# Fetching match: TW2_44547757
# Fetching match: VN2_48364194
# Fetching match: LA1_1367110448
# Fetching match: PH2_6677634
# Fetching match: EUN1_3338590569
# Fetching match: KR_6418459910
# Fetching match: TR1_1391514708
# Fetching match: NA1_4609940207
# Fetching match: EUN1_3337328284
# Fetching match: KR_6418518700
# Fetching match: RU_435130413
# Fetching match: SG2_4906605
# Fetching match: BR1_2698598919
# Fetching match: PH2_8368660
# Fetching match: JP1_391014960
# Fetching match: EUN1_3338570448
# Fetching match: EUW1_6328943179
# Fetching match: KR_6416662696
# Fetching match: PH2_8115426
# Fetching match: EUW1_6327344937
# Fetching match: NA1_4609133311
# Fetching match: BR1_2701093254
# Fetching match: EUN1_3334645571
# Fetching match: LA2_1280785202
# Fetching match: LA1_1369947875
# Fetching match: KR_6409476560
# Fetching match: LA2_1280836901
# Fetching match: KR_6407433862
# Fetching match: PH2_8386546
# Fetching match: VN2_53036818
# Fetching match: NA1_4598915955
# Fetching match: NA1_4607030101
# Fetching match: PH2_7392186
# Fetching match: BR1_2688108992
# Fetching match: LA2_1280780718
# Fetching match: EUW1_6322730170
# Fetching match: VN2_46840506
# Fetching match: SG2_4759284
# Fetching match: LA1_1368239888
# Fetching match: TW2_47888251
# Fetching match: EUW1_6326555008
# Fetching match: EUN1_3338225104
# Fetching match: BR1_2698080696
# Fetching match: TW2_45318102
# Fetching match: TR1_1392111783
# Fetching match: EUN1_3337332786
# Fetching match: PH2_8322905
# Fetching match: EUN1_3335771264
# Fetching match: OC1_563365229
# Fetching match: EUW1_6321346589
# Fetching match: KR_6414374732
# Fetching match: EUW1_6318168306
# Fetching match: EUW1_6321439822
# Fetching match: LA1_1368927833
# Fetching match: NA1_4608221274
# Fetching match: TR1_1390769015
# Fetching match: TW2_45952971
# Fetching match: PH2_8047501
# Fetching match: PH2_8509487
# Fetching match: TW2_48101808
# Fetching match: VN2_54170960
# Fetching match: NA1_4607117887
# Fetching match: LA2_1280282776
# Fetching match: KR_6412459086
# Fetching match: LA2_1277568638
# Fetching match: PH2_7619207
# Fetching match: KR_6409573956
# Fetching match: PH2_7585784
# Fetching match: EUW1_6327399193
# Fetching match: VN2_54172897
# Fetching match: JP1_390967799
# Fetching match: TW2_48232778
# Fetching match: TH2_3574300
# Fetching match: PH2_7462583
# Fetching match: TW2_45266452
# Fetching match: TW2_48502001
# Fetching match: SG2_4865146
# Fetching match: NA1_4607309469
# Fetching match: TR1_1391879386
# Fetching match: LA2_1280776971
# Fetching match: NA1_4605025203
# Fetching match: VN2_53879407
# Fetching match: LA2_1280156069
# Fetching match: PH2_8066119
# Fetching match: LA1_1369284525
# Fetching match: JP1_389887100
# Fetching match: LA1_1369899555
# Fetching match: TR1_1390175009
# Fetching match: EUN1_3335480661
# Fetching match: VN2_52185421
# Fetching match: LA1_1369016112
# Fetching match: BR1_2701277998
# Fetching match: EUN1_3330543547
# Fetching match: TR1_1392207548
# Fetching match: TW2_49046649
# Fetching match: EUN1_3336219619
# Fetching match: TR1_1388082921
# Fetching match: PH2_7933362
# Fetching match: TR1_1392303021
# Fetching match: LA2_1280837190
# Fetching match: VN2_54027706
# Fetching match: NA1_4602812108
# Fetching match: SG2_4903071
# Fetching match: BR1_2696099817
# Fetching match: BR1_2699734969
# Fetching match: LA1_1369896264
# Fetching match: EUW1_6323479768
# Fetching match: BR1_2701104736
# Fetching match: EUN1_3337441448
# Fetching match: VN2_53401525
# Fetching match: TW2_47969050
# Fetching match: KR_6411013396
# Fetching match: PH2_8058508
# Fetching match: TR1_1391625517
# Fetching match: NA1_4595793214
# Fetching match: TW2_47808507
# Fetching match: EUW1_6328249895
# Fetching match: BR1_2696693300
# Fetching match: OC1_563608309
# Fetching match: PH2_8335855
# Fetching match: LA2_1280238852
# Fetching match: KR_6405638132
# Fetching match: LA2_1280904425
# Fetching match: RU_434872274
# Fetching match: RU_434945660
# Fetching match: TR1_1391609130
# Fetching match: TH2_3589957
# Fetching match: VN2_45544736
# Fetching match: PH2_7919107
# Fetching match: NA1_4607633616
# Fetching match: NA1_4605854552
# Fetching match: LA1_1369668733
# Fetching match: EUN1_3329942367
# Fetching match: LA2_1280764828
# Fetching match: TR1_1391803032
# Fetching match: PH2_8438793
# Fetching match: OC1_563261024
# Fetching match: LA2_1280361084
# Fetching match: LA2_1279762830
# Fetching match: NA1_4605069979
# Fetching match: TW2_48955772
# Fetching match: TW2_47067321
# Fetching match: LA2_1280768389
# Fetching match: NA1_4607456776
# Fetching match: VN2_52923882
# Fetching match: TW2_46572243
# Fetching match: BR1_2699660692
# Fetching match: LA1_1369098315
# Fetching match: NA1_4608168753
# Fetching match: PH2_8252693
# Fetching match: LA1_1369883647
# Fetching match: LA2_1278801382
# Fetching match: OC1_563689272
# Fetching match: VN2_52906331
# Fetching match: TH2_3553085
# Fetching match: NA1_4606209173
# Fetching match: LA2_1280460143
# Fetching match: BR1_2693769401
# Fetching match: TR1_1391120859
# Fetching match: NA1_4605896971
# Fetching match: KR_6393738903
# Fetching match: TW2_47955856
# Fetching match: EUN1_3336699209
# Fetching match: KR_6413220514
# Fetching match: PH2_7872028
# Fetching match: LA2_1280430430
# Fetching match: VN2_43674295
# Fetching match: RU_433513852
# Fetching match: BR1_2701277847
# Fetching match: LA1_1364847125
# Fetching match: EUN1_3332725623
# Fetching match: EUN1_3331799903
# Fetching match: VN2_52934553
# Fetching match: LA1_1368582637
# Fetching match: LA1_1368514370
# Fetching match: KR_6414423611
# Fetching match: KR_6404582124
# Fetching match: VN2_53249897
# Fetching match: EUN1_3337436754
# Fetching match: KR_6411082368
# Fetching match: OC1_562905218
# Fetching match: NA1_4603516106
# Fetching match: KR_6415909886
# Fetching match: VN2_45769985
# Fetching match: PH2_7760719
# Fetching match: EUN1_3329203174
# Fetching match: PH2_7533297
# Fetching match: TR1_1391570410
# Fetching match: BR1_2697965113
# Fetching match: NA1_4607273093
# Fetching match: TW2_48448092
# Fetching match: EUW1_6328827203
# Fetching match: BR1_2695899205
# Fetching match: LA2_1280717950
# Fetching match: PH2_8413814
# Fetching match: VN2_49142070
# Fetching match: PH2_7770929
# Fetching match: KR_6411502793
# Fetching match: KR_6418350449
# Fetching match: TR1_1392395359
# Fetching match: BR1_2697647009
# Fetching match: JP1_388996780
# Fetching match: LA1_1369614846
# Fetching match: NA1_4596517588
# Fetching match: RU_434439118
# Fetching match: NA1_4608204847
# Fetching match: TR1_1390953158
# Fetching match: EUN1_3334898696
# Fetching match: VN2_52948831
# Fetching match: EUW1_6326255228
# Fetching match: LA1_1369301822
# Fetching match: PH2_8129309
# Fetching match: VN2_48986285
# Fetching match: TR1_1392024090
# Fetching match: LA2_1279864209
# Fetching match: LA2_1278251276
# Fetching match: NA1_4610089643
# Fetching match: VN2_53229845
# Fetching match: TW2_47215401
# Fetching match: EUN1_3334541387
# Fetching match: LA2_1279630056
# Fetching match: SG2_4855741
# Fetching match: PH2_8027710
# Fetching match: TW2_47544070
# Fetching match: BR1_2693535206
# Fetching match: LA1_1368875816
# Fetching match: EUW1_6314370919
# Fetching match: EUN1_3334885488
# Fetching match: VN2_52498342
# Fetching match: VN2_53421640
# Fetching match: EUN1_3338529573
# Fetching match: VN2_53060877
# Fetching match: LA2_1278213913
# Fetching match: PH2_7600683
# Fetching match: PH2_7623213
# Fetching match: LA2_1280531587
# Fetching match: TR1_1392219439
# Fetching match: VN2_54063856
# Fetching match: VN2_49420533
# Fetching match: VN2_50438019
# Fetching match: LA2_1279519646
# Fetching match: PH2_7684917
# Fetching match: NA1_4607976057
# Fetching match: EUN1_3336886929
# Fetching match: VN2_50487952
# Fetching match: VN2_53072355
# Fetching match: TW2_48392292
# Fetching match: TR1_1389164948
# Fetching match: KR_6418067658
# Fetching match: KR_6415686112
# Fetching match: TR1_1390329528
# Fetching match: TW2_48281480
# Fetching match: PH2_7151525
# Fetching match: OC1_563534477
# Fetching match: BR1_2697173493
# Fetching match: JP1_390832715
# Fetching match: NA1_4603549706
# Fetching match: VN2_53958566
# Fetching match: TR1_1391657499
# Fetching match: NA1_4603188335
# Fetching match: TW2_48584196
# Fetching match: EUW1_6327717638
# Fetching match: NA1_4607707408
# Fetching match: BR1_2700131578
# Fetching match: TR1_1390797530
# Fetching match: EUW1_6329158154
# Fetching match: LA2_1280693460
# Fetching match: TR1_1389749554
# Fetching match: EUW1_6329058572
# Fetching match: TR1_1392096985
# Fetching match: LA1_1369262597
# Fetching match: BR1_2697324520
# Fetching match: VN2_47012002
# Fetching match: LA1_1367115872
# Fetching match: LA2_1279833090
# Fetching match: BR1_2693937922
# Fetching match: OC1_563678729
# Fetching match: TW2_48983557
# Fetching match: EUW1_6329175057
# Fetching match: VN2_48608895
# Fetching match: PH2_7698086
# Fetching match: LA2_1278526454
# Fetching match: KR_6413170683
# Fetching match: TR1_1388579646
# Fetching match: OC1_563210657
# Fetching match: TR1_1391454112
# Fetching match: TW2_47722193
# Fetching match: EUN1_3336995507
# Fetching match: EUN1_3336470936
# Fetching match: TH2_3526470
# Fetching match: TR1_1390999735
# Fetching match: PH2_8471911
# Fetching match: VN2_53487069
# Fetching match: EUW1_6317105194
# Fetching match: NA1_4602945612
# Fetching match: SG2_4913471
# Fetching match: KR_6414442420
# Fetching match: TW2_49134279
# Fetching match: PH2_8286554
# Fetching match: OC1_563021700
# Fetching match: TW2_48754762
# Fetching match: LA1_1368468148
# Fetching match: EUN1_3337928240
# Fetching match: LA2_1279580303
# Fetching match: TR1_1391257970
# Fetching match: EUW1_6319846998
# Fetching match: KR_6419083274
# Fetching match: PH2_7192762
# Fetching match: NA1_4607950736
# Fetching match: EUW1_6327358535
# Fetching match: BR1_2699148595
# Fetching match: TW2_48200104
# Fetching match: PH2_8244979
# Fetching match: OC1_563542946
# Fetching match: TW2_48635375
# Fetching match: BR1_2697673262
# Fetching match: BR1_2700489604
# Fetching match: KR_6406783853
# Fetching match: NA1_4600208688
# Fetching match: LA1_1368167746
# Fetching match: BR1_2694699295
# Fetching match: TW2_48332190
# Fetching match: EUN1_3336738537
# Fetching match: LA1_1369162669
# Fetching match: VN2_49669902
# Fetching match: TW2_48675014
# Fetching match: BR1_2694435223
# Fetching match: VN2_53781106
# Fetching match: BR1_2701311879
# Fetching match: EUN1_3337580175
# Fetching match: VN2_52721027
# Fetching match: OC1_563613748
# Fetching match: VN2_50274028
# Fetching match: NA1_4606612831
# Fetching match: BR1_2700555825
# Fetching match: LA2_1279705608
# Fetching match: LA1_1367154487
# Fetching match: TR1_1391917130
# Fetching match: BR1_2696645309
# Fetching match: LA1_1364394515
# Fetching match: TR1_1392056784
# Fetching match: TR1_1392014378
# Fetching match: PH2_8057104
# Fetching match: TR1_1391750251
# Fetching match: VN2_48014867
# Fetching match: VN2_52639999
# Fetching match: OC1_563768810
# Fetching match: VN2_53741761
# Fetching match: LA1_1369874578
# Fetching match: TR1_1391657190
# Fetching match: EUW1_6323217636
# Fetching match: KR_6418966667
# Fetching match: TW2_48623597
# Fetching match: LA1_1368230459
# Fetching match: LA2_1278527646
# Fetching match: NA1_4605917404
# Fetching match: BR1_2701187010
# Fetching match: LA1_1369906984
# Fetching match: EUN1_3337453734
# Fetching match: LA2_1280099645
# Fetching match: TR1_1392097566
# Fetching match: TW2_47984903
# Fetching match: LA1_1369751632
# Fetching match: KR_6410061109
# Fetching match: TH2_3142684
# Fetching match: EUW1_6323045679
# Fetching match: EUW1_6329361013
# Fetching match: EUN1_3335539765
# Fetching match: EUW1_6326871851
# Fetching match: EUN1_3338297264
# Fetching match: EUN1_3336759680
# Fetching match: VN2_52947843
# Fetching match: TR1_1391820480
# Fetching match: EUN1_3337362419
# Fetching match: TW2_46609314
# Fetching match: RU_432866104
# Fetching match: TW2_46901094
# Fetching match: TR1_1392143556
# Fetching match: LA2_1277237745
# Fetching match: NA1_4606605818
# Fetching match: LA1_1369113878
# Fetching match: BR1_2696793676
# Fetching match: VN2_53554110
# Fetching match: TW2_43258189
# Fetching match: LA2_1278693250
# Fetching match: OC1_563704803
# Fetching match: TW2_47812174
# Fetching match: EUN1_3337369869
# Fetching match: SG2_4849920
# Fetching match: SG2_4751490
# Fetching match: BR1_2700243096
# Fetching match: VN2_53930474
# Fetching match: EUW1_6322907474
# Fetching match: JP1_390959901
# Fetching match: EUN1_3337931692
# Fetching match: KR_6413292377
# Fetching match: LA1_1368413133
# Fetching match: BR1_2700634363
# Fetching match: NA1_4608633134
# Fetching match: PH2_8453023
# Fetching match: TR1_1390747585
# Fetching match: LA2_1280669541
# Fetching match: NA1_4605797497
# Fetching match: LA2_1280157667
# Fetching match: NA1_4594083071
# Fetching match: EUN1_3337131848
# Fetching match: VN2_52179483
# Fetching match: LA1_1369138913
# Fetching match: TW2_48585377
# Fetching match: TR1_1391631277
# Fetching match: BR1_2696240124
# Fetching match: VN2_51852079
# Fetching match: LA2_1280538761
# Fetching match: EUN1_3338342778
# Fetching match: LA2_1279882127
# Fetching match: EUW1_6327397950
# Fetching match: EUW1_6316730857
# Fetching match: LA1_1369351322
# Fetching match: TW2_47829655
# Fetching match: LA1_1367404675
# Fetching match: EUN1_3336073065
# Fetching match: EUW1_6323928044
# Fetching match: OC1_563760097
# Fetching match: PH2_8461381
# Fetching match: TR1_1389945165
# Fetching match: KR_6419382527
# Fetching match: NA1_4606662985
# Fetching match: TW2_48645426
# Fetching match: EUW1_6324628605
# Fetching match: NA1_4602390284
# Fetching match: VN2_51856664
# Fetching match: LA1_1368891064
# Fetching match: TW2_47064141
# Fetching match: TH2_3041716
# Fetching match: EUW1_6327295582
# Fetching match: PH2_7717298
# Fetching match: BR1_2699838871
# Fetching match: RU_435059213
# Fetching match: KR_6413713410
# Fetching match: LA1_1364995001
# Fetching match: TR1_1390742899
# Fetching match: LA1_1368134682
# Fetching match: TR1_1392343620
# Fetching match: EUW1_6326777989
# Fetching match: TW2_48165537
# Fetching match: EUN1_3334075175
# Fetching match: LA1_1369447211
# Fetching match: RU_433796395
# Fetching match: EUN1_3337899345
# Fetching match: LA2_1280397108
# Fetching match: PH2_7600902
# Fetching match: EUN1_3338246690
# Fetching match: EUW1_6326882152
# Fetching match: EUN1_3335504262
# Fetching match: KR_6406475193
# Fetching match: LA1_1365993817
# Fetching match: VN2_49869618
# Fetching match: TW2_46461390
# Fetching match: TW2_42947008
# Fetching match: EUN1_3331840792
# Fetching match: EUN1_3338271642
# Fetching match: LA1_1366789182
# Fetching match: PH2_8527963
# Fetching match: VN2_53783594
# Fetching match: EUN1_3336966876
# Fetching match: EUN1_3337561722
# Fetching match: PH2_8459433
# Fetching match: BR1_2701169685
# Fetching match: EUN1_3336463011
# Fetching match: EUW1_6324883759
# Fetching match: TR1_1391593875
# Fetching match: LA2_1280837722
# Fetching match: SG2_4788272
# Fetching match: PH2_8385282
# Fetching match: TW2_46105399
# Fetching match: LA1_1366602086
# Fetching match: VN2_50404793
# Fetching match: BR1_2700947570
# Fetching match: TW2_48344732
# Fetching match: KR_6412188875
# Fetching match: LA1_1369354224
# Fetching match: LA2_1280679436
# Fetching match: PH2_7640309
# Fetching match: PH2_7736315
# Fetching match: NA1_4604904907
# Fetching match: BR1_2700208089
# Fetching match: VN2_53648296
# Fetching match: LA2_1280596499
# Fetching match: KR_6405246020
# Fetching match: VN2_43036136
# Fetching match: KR_6414288292
# Fetching match: TR1_1392429964
# Fetching match: TW2_46147160
# Fetching match: EUW1_6313941342
# Fetching match: LA2_1280490408
# Fetching match: BR1_2700394171
# Fetching match: EUN1_3338686183
# Fetching match: BR1_2699944403
# Fetching match: VN2_53172459
# Fetching match: LA1_1369210569
# Fetching match: LA1_1369770603
# Fetching match: BR1_2699672560
# Fetching match: PH2_7005982
# Fetching match: TW2_47894494
# Fetching match: TH2_3217969
# Fetching match: LA2_1280628841
# Fetching match: LA1_1369381457
# Fetching match: EUN1_3337990011
# Fetching match: JP1_389814643
# Fetching match: EUN1_3337224202
# Fetching match: JP1_390964141
# Fetching match: LA1_1366558342
# Fetching match: LA2_1279718484
# Fetching match: EUN1_3336626963
# Fetching match: VN2_53902558
# Fetching match: PH2_8504818
# Fetching match: TW2_47345633
# Fetching match: LA1_1368709527
# Fetching match: LA2_1280634842
# Fetching match: TR1_1392347221
# Fetching match: VN2_51799416
# Fetching match: NA1_4601018706
# Fetching match: EUN1_3335582909
# Fetching match: KR_6415395226
# Fetching match: LA2_1280351008
# Fetching match: BR1_2693856015
# Fetching match: LA1_1369687577
# Fetching match: EUW1_6324732449
# Fetching match: JP1_389719741
# Fetching match: TR1_1392386511
# Fetching match: OC1_563127527
# Fetching match: PH2_8288725
# Fetching match: LA1_1369890262
# Fetching match: KR_6416826647
# Fetching match: KR_6417769907
# Fetching match: PH2_7862487
# Fetching match: NA1_4605151247
# Fetching match: KR_6418260440
# Fetching match: VN2_54074338
# Fetching match: VN2_53009730
# Fetching match: PH2_7620591
# Fetching match: VN2_51585878
# Fetching match: BR1_2701220309
# Fetching match: EUN1_3331335187
# Fetching match: KR_6413144783
# Fetching match: BR1_2697954391
# Fetching match: OC1_563403273
# Fetching match: TH2_3202782
# Fetching match: PH2_6157770
# Fetching match: SG2_4509276
# Fetching match: EUN1_3338140771
# Fetching match: LA1_1368258449
# Fetching match: NA1_4608349628
# Fetching match: NA1_4600368698
# Fetching match: TR1_1389577967
# Fetching match: LA2_1280626999
# Fetching match: NA1_4601894696
# Fetching match: NA1_4606499150
# Fetching match: TW2_48634243
# Fetching match: NA1_4602221079
# Fetching match: TW2_45905911
# Fetching match: JP1_390837602
# Fetching match: NA1_4606292275
# Fetching match: LA1_1369213725
# Fetching match: RU_434965321
# Fetching match: RU_435025109
# Fetching match: PH2_7372523
# Fetching match: LA2_1280612338
# Fetching match: TH2_3558183
# Fetching match: LA1_1369317108
# Fetching match: LA1_1369934375
# Fetching match: TR1_1392016925
# Fetching match: TW2_47777876
# Fetching match: NA1_4594412781
# Fetching match: BR1_2696146272
# Fetching match: EUN1_3335519029
# Fetching match: LA1_1368298003
# Fetching match: LA2_1280551237
# Fetching match: VN2_53085921
# Fetching match: NA1_4602156251
# Fetching match: NA1_4607995535
# Fetching match: TW2_47829748
# Fetching match: TR1_1392415037
# Fetching match: LA2_1278918446
# Fetching match: BR1_2697479842
# Fetching match: LA1_1369617383
# Fetching match: VN2_50741571
# Fetching match: NA1_4608462550
# Fetching match: VN2_53370451
# Fetching match: TR1_1390412213
# Fetching match: TR1_1392449303
# Fetching match: LA1_1367809355
# Fetching match: TW2_48690294
# Fetching match: EUW1_6302102357
# Fetching match: EUW1_6326605294
# Fetching match: KR_6416770622
# Fetching match: EUW1_6314949498
# Fetching match: LA1_1368203624
# Fetching match: LA2_1278801565
# Fetching match: TH2_3334330
# Fetching match: TW2_45160267
# Fetching match: VN2_51839769
# Fetching match: KR_6416550434
# Fetching match: KR_6404702344
# Fetching match: VN2_53349627
# Fetching match: NA1_4610025322
# Fetching match: TR1_1391753995
# Fetching match: PH2_8517992
# Fetching match: LA2_1279883807
# Fetching match: JP1_390720240
# Fetching match: KR_6413277561
# Fetching match: BR1_2694127681
# Fetching match: EUN1_3335550980
# Fetching match: VN2_45048623
# Fetching match: LA2_1280560519
# Fetching match: EUW1_6321583759
# Fetching match: EUW1_6322960477
# Fetching match: NA1_4606511959
# Fetching match: EUW1_6298630677
# Fetching match: EUN1_3334434122
# Fetching match: PH2_8147278
# Fetching match: NA1_4609322184
# Fetching match: TH2_3560102
# Fetching match: PH2_7773011
# Fetching match: NA1_4603328933
# Fetching match: KR_6399392654
# Fetching match: EUW1_6309263989
# Fetching match: KR_6416760209
# Fetching match: KR_6416868883
# Fetching match: JP1_390088698
# Fetching match: LA1_1368913903
# Fetching match: KR_6416372892
# Fetching match: NA1_4609230702
# Fetching match: TW2_47804795
# Fetching match: VN2_48638478
# Fetching match: EUN1_3337621464
# Fetching match: TW2_46154240
# Fetching match: RU_432858027
# Fetching match: NA1_4607098083
# Fetching match: BR1_2698522403
# Fetching match: TR1_1391280837
# Fetching match: NA1_4609700801
# Fetching match: VN2_52894615
# Fetching match: BR1_2700327120
# Fetching match: PH2_8452051
# Fetching match: LA1_1366327307
# Fetching match: NA1_4609758433
# Fetching match: SG2_4386647
# Fetching match: BR1_2701248773
# Fetching match: LA2_1280367809
# Fetching match: BR1_2701295060
# Fetching match: KR_6414802314
# Fetching match: TW2_47267184
# Fetching match: LA1_1367519434
# Fetching match: NA1_4608306584
# Fetching match: RU_433823731
# Fetching match: TR1_1392261915
# Fetching match: TW2_46575935
# Fetching match: PH2_7946256
# Fetching match: EUW1_6321687715
# Fetching match: PH2_8360795
# Fetching match: TW2_48168186
# Fetching match: EUN1_3335227667
# Fetching match: TW2_44570594
# Fetching match: LA2_1280709307
# Fetching match: BR1_2693993856
# Fetching match: EUW1_6327388508
# Fetching match: EUN1_3338085972
# Fetching match: VN2_53704049
# Fetching match: KR_6418815150
# Fetching match: SG2_4876425
# Fetching match: LA2_1277871285
# Fetching match: EUN1_3338695646
# Fetching match: BR1_2694141692
# Fetching match: TW2_42870855
# Fetching match: VN2_52955266
# Fetching match: PH2_8455693
# Fetching match: TR1_1391422597
# Fetching match: EUW1_6323767682
# Fetching match: OC1_563138168
# Fetching match: RU_434949987
# Fetching match: PH2_8425585
# Fetching match: NA1_4601278268
# Fetching match: PH2_8357267
# Fetching match: PH2_7535956
# Fetching match: LA2_1280370561
# Fetching match: OC1_563339671
# Fetching match: VN2_47874503
# Fetching match: VN2_47440092
# Fetching match: OC1_563000548
# Fetching match: TR1_1391758245
# Fetching match: PH2_7637007
# Fetching match: EUW1_6320050946
# Fetching match: LA2_1280857763
# Fetching match: NA1_4609090970
# Fetching match: VN2_51573705
# Fetching match: NA1_4605519565
# Fetching match: VN2_54121731
# Fetching match: LA1_1367353248
# Fetching match: BR1_2700741303
# Fetching match: TR1_1391743888
# Fetching match: OC1_563401153
# Fetching match: VN2_46505176
# Fetching match: EUW1_6317751922
# Fetching match: EUW1_6325010828
# Fetching match: EUN1_3334093034
# Fetching match: VN2_51529595
# Fetching match: EUN1_3336747589
# Fetching match: PH2_7483555
# Fetching match: BR1_2697768246
# Fetching match: EUN1_3337297540
# Fetching match: LA1_1369571987
# Fetching match: LA1_1368873209
# Fetching match: EUW1_6326758249
# Fetching match: JP1_390573610
# Fetching match: TW2_47768749
# Fetching match: LA1_1368143950
# Fetching match: SG2_4873526
# Fetching match: EUN1_3337971751
# Fetching match: EUW1_6320761504
# Fetching match: TR1_1390663481
# Fetching match: BR1_2693347875
# Fetching match: KR_6419393122
# Fetching match: KR_6397653858
# Fetching match: NA1_4605462836
# Fetching match: VN2_46459312
# Fetching match: LA2_1279726375
# Fetching match: TR1_1391601663
# Fetching match: LA1_1368444181
# Fetching match: BR1_2699284934
# Fetching match: TR1_1391907252
# Fetching match: LA2_1280175662
# Fetching match: TW2_48092652
# Fetching match: BR1_2700642796
# Fetching match: EUW1_6318535939
# Fetching match: JP1_390354205
# Fetching match: TR1_1391329827
# Fetching match: OC1_563348665
# Fetching match: EUW1_6302395243
# Fetching match: LA2_1280352688
# Fetching match: BR1_2700214441
# Fetching match: KR_6416689714
# Fetching match: LA1_1369342208
# Fetching match: LA1_1369838453
# Fetching match: EUW1_6327455911
# Fetching match: EUW1_6329273459
# Fetching match: KR_6413766717
# Fetching match: TR1_1392004658
# Fetching match: VN2_50700802
# Fetching match: BR1_2698153841
# Fetching match: NA1_4607165395
# Fetching match: PH2_8520300
# Fetching match: PH2_7625977
# Fetching match: LA1_1366486733
# Fetching match: TW2_48290743
# Fetching match: BR1_2690284405
# Fetching match: LA2_1275451805
# Fetching match: BR1_2701160537
# Fetching match: EUN1_3336773464
# Fetching match: EUN1_3334445253
# Fetching match: EUW1_6325119208
# Fetching match: KR_6414343664
# Fetching match: EUW1_6329125347
# Fetching match: LA1_1368053840
# Fetching match: NA1_4609950248
# Fetching match: KR_6405898001
# Fetching match: LA2_1280298771
# Fetching match: NA1_4610119905
# Fetching match: LA2_1280227938
# Fetching match: LA2_1278038433
# Fetching match: TH2_3473500
# Fetching match: LA2_1280383034
# Fetching match: BR1_2700857031
# Fetching match: PH2_8014701
# Fetching match: TR1_1391616742
# Fetching match: EUW1_6316752440
# Fetching match: NA1_4606371562
# Fetching match: TR1_1389980274
# Fetching match: LA1_1369811777
# Fetching match: NA1_4610092190
# Fetching match: TW2_48070989
# Fetching match: OC1_563017999
# Fetching match: VN2_53216379
# Fetching match: JP1_390628908
# Fetching match: TH2_3369244
# Fetching match: EUW1_6328226031
# Fetching match: OC1_563252148
# Fetching match: KR_6418672424
# Fetching match: LA1_1369378053
# Fetching match: EUN1_3338083078
# Fetching match: RU_434759749
# Fetching match: TR1_1392495252
# Fetching match: TR1_1391284430
# Fetching match: EUW1_6322345751
# Fetching match: BR1_2696420091
# Fetching match: VN2_54017039
# Fetching match: RU_434838912
# Fetching match: VN2_52115797
# Fetching match: KR_6417183018
# Fetching match: LA1_1367938995
# Fetching match: TW2_48933085
# Fetching match: PH2_7966889
# Fetching match: NA1_4602564015
# Fetching match: NA1_4606358144
# Fetching match: TR1_1392014942
# Fetching match: TR1_1392399224
# Fetching match: TW2_48845105
# Fetching match: BR1_2701198147
# Fetching match: EUW1_6324738059
# Fetching match: TW2_47582636
# Fetching match: BR1_2698677961
# Fetching match: VN2_53786084
# Fetching match: KR_6411768830
# Fetching match: LA2_1279714704
# Fetching match: BR1_2696073034
# Fetching match: TR1_1391129936
# Fetching match: PH2_8374895
# Fetching match: NA1_4609038536
# Fetching match: BR1_2695202062
# Fetching match: LA1_1369674067
# Fetching match: NA1_4605433242
# Fetching match: NA1_4595881755
# Fetching match: BR1_2699540137
# Fetching match: RU_434936074
# Fetching match: BR1_2697733623
# Fetching match: NA1_4608244700
# Fetching match: LA2_1278471374
# Fetching match: LA1_1364267027
# Fetching match: TW2_48716561
# Fetching match: NA1_4608055607
# Fetching match: VN2_51543393
# Fetching match: BR1_2697577931
# Fetching match: NA1_4608392924
# Fetching match: LA1_1369893430
# Fetching match: TW2_37861745
# Fetching match: BR1_2700245045
# Fetching match: LA1_1369179883
# Fetching match: KR_6414061920
# Fetching match: NA1_4608048573
# Fetching match: RU_434480824
# Fetching match: PH2_7467859
# Fetching match: BR1_2700135801
# Fetching match: OC1_562313388
# Fetching match: TR1_1391737087
# Fetching match: TW2_48300950
# Fetching match: BR1_2699852620
# Fetching match: JP1_389289065
# Fetching match: EUN1_3338571655
# Fetching match: PH2_7895131
# Fetching match: LA1_1368957433
# Fetching match: RU_435030433
# Fetching match: TR1_1392418408
# Fetching match: TW2_47987955
# Fetching match: TH2_3352932
# Fetching match: JP1_390679173
# Fetching match: LA1_1367761826
# Fetching match: RU_435112797
# Fetching match: EUN1_3336005359
# Fetching match: PH2_6996817
# Fetching match: KR_6416761567
# Fetching match: EUN1_3335600079
# Fetching match: EUW1_6306779935
# Fetching match: VN2_52004012
# Fetching match: EUW1_6326020266
# Fetching match: VN2_52198818
# Fetching match: RU_434818083
# Fetching match: JP1_391053576
# Fetching match: VN2_52414362
# Fetching match: BR1_2700915127
# Fetching match: TR1_1391633007
# Fetching match: TR1_1388452017
# Fetching match: LA2_1280689783
# Fetching match: VN2_53937816
# Fetching match: TR1_1392370754
# Fetching match: SG2_4910386
# Fetching match: EUW1_6313128559
# Fetching match: VN2_53988937
# Fetching match: TW2_47937238
# Fetching match: SG2_4857101
# Fetching match: NA1_4609996950
# Fetching match: NA1_4604554979
# Fetching match: LA1_1369832899
# Fetching match: LA2_1279086233
# Fetching match: LA2_1280218361
# Fetching match: LA1_1367343399
# Fetching match: BR1_2701351358
# Fetching match: NA1_4606118577
# Fetching match: VN2_51773441
# Fetching match: EUN1_3336204619
# Fetching match: TH2_2853367
# Fetching match: TW2_47194726
# Fetching match: VN2_54159266
# Fetching match: BR1_2698826035
# Fetching match: BR1_2694507732
# Fetching match: EUW1_6324018793
# Fetching match: LA1_1366169445
# Fetching match: BR1_2699819571
# Fetching match: LA2_1275637680
# Fetching match: EUW1_6325845455
# Fetching match: BR1_2700823717
# Fetching match: VN2_48254382
# Fetching match: EUN1_3338030866
# Fetching match: SG2_4680321
# Fetching match: NA1_4607884358
# Fetching match: TH2_3556720
# Fetching match: VN2_52679871
# Fetching match: PH2_8438097
# Fetching match: LA1_1368562058
# Fetching match: TR1_1390427154
# Fetching match: TR1_1392058697
# Fetching match: RU_434620748
# Fetching match: BR1_2699631728
# Fetching match: LA1_1368603334
# Fetching match: TR1_1391720321
# Fetching match: OC1_563701511
# Fetching match: OC1_563200937
# Fetching match: LA1_1369026032
# Fetching match: OC1_561877743
# Fetching match: LA1_1369321769
# Fetching match: EUW1_6324608448
# Fetching match: NA1_4599500107
# Fetching match: LA2_1277710109
# Fetching match: BR1_2699915236
# Fetching match: NA1_4610003823
# Fetching match: NA1_4606856538
# Fetching match: NA1_4606889997
# Fetching match: LA1_1368549831
# Fetching match: LA2_1280173978
# Fetching match: LA1_1368096195
# Fetching match: LA1_1367284948
# Fetching match: LA1_1366995040
# Fetching match: EUW1_6327307287
# Fetching match: NA1_4609630013
# Fetching match: TH2_3509939
# Fetching match: SG2_4806830
# Fetching match: EUW1_6322956581
# Fetching match: JP1_390365566
# Fetching match: LA2_1280026963
# Fetching match: EUW1_6328805219
# Fetching match: EUW1_6327462916
# Fetching match: PH2_7483658
# Fetching match: EUW1_6329054464
# Fetching match: LA2_1278577799
# Fetching match: TW2_45816786
# Fetching match: VN2_54061887
# Fetching match: TW2_48660689
# Fetching match: VN2_54167951
# Fetching match: EUW1_6325955237
# Fetching match: KR_6407312633
# Fetching match: NA1_4608887811
# Fetching match: NA1_4604669896
# Fetching match: NA1_4603530152
# Fetching match: TH2_3326878
# Fetching match: TR1_1392120070
# Fetching match: EUW1_6322123429
# Fetching match: TW2_47903309
# Fetching match: BR1_2700822282
# Fetching match: TW2_42736713
# Fetching match: LA2_1276275603
# Fetching match: EUN1_3333626999
# Fetching match: LA2_1280867418
# Fetching match: KR_6411274053
# Fetching match: EUW1_6317746656
# Fetching match: EUW1_6311695770
# Fetching match: VN2_43245050
# Fetching match: LA1_1368789572
# Fetching match: EUW1_6324220042
# Fetching match: LA2_1280869044
# Fetching match: VN2_34697825
# Fetching match: VN2_46859401
# Fetching match: EUW1_6325414685
# Fetching match: VN2_52891555
# Fetching match: NA1_4602126218
# Fetching match: TW2_47113558
# Fetching match: EUW1_6315357709
# Fetching match: LA1_1369410853
# Fetching match: NA1_4609023886
# Fetching match: EUW1_6328182376
# Fetching match: NA1_4601197120
# Fetching match: LA2_1278737567
# Fetching match: EUW1_6327678614
# Fetching match: BR1_2700785599
# Fetching match: NA1_4596485621
# Fetching match: TW2_47218668
# Fetching match: VN2_53632925
# Fetching match: PH2_8456932
# Fetching match: EUN1_3336529913
# Fetching match: TR1_1392036726
# Fetching match: LA2_1280319828
# Fetching match: RU_434630900
# Fetching match: KR_6418130980
# Fetching match: TW2_47464877
# Fetching match: BR1_2701378301
# Fetching match: LA1_1369192187
# Fetching match: TW2_48308600
# Fetching match: LA1_1369249817
# Fetching match: BR1_2697932320
# Fetching match: EUW1_6326992878
# Fetching match: LA2_1280801748
# Fetching match: EUW1_6324699083
# Fetching match: LA2_1280412112
# Fetching match: KR_6417238372
# Fetching match: LA2_1280194332
# Fetching match: VN2_54080252
# Fetching match: LA2_1280002830
# Fetching match: LA2_1280209684
# Fetching match: TW2_48127663
# Fetching match: LA2_1280697959
# Fetching match: EUW1_6327287955
# Fetching match: BR1_2700777581
# Fetching match: TR1_1390025270
# Fetching match: LA2_1279785235
# Fetching match: NA1_4606172702
# Fetching match: EUW1_6328409546
# Fetching match: TR1_1388409142
# Fetching match: LA2_1279474401
# Fetching match: EUW1_6324440406
# Fetching match: BR1_2700283754
# Fetching match: LA1_1365517250
# Fetching match: NA1_4608608603
# Fetching match: EUN1_3338682430
# Fetching match: LA1_1369351057
# Fetching match: NA1_4599932954
# Fetching match: TW2_47989022
# Fetching match: LA2_1278363204
# Fetching match: LA2_1279166243
# Fetching match: PH2_7704035
# Fetching match: RU_434540379
# Fetching match: LA2_1279823352
# Fetching match: LA2_1280763834
# Fetching match: PH2_8272383
# Fetching match: NA1_4606229646
# Fetching match: TW2_45011758
# Fetching match: VN2_52052311
# Fetching match: KR_6418395803
# Fetching match: VN2_52130794
# Fetching match: VN2_53678209
# Fetching match: EUW1_6326830346
# Fetching match: EUN1_3330408650
# Fetching match: OC1_563649391
# Fetching match: TR1_1388161331
# Fetching match: BR1_2699842597
# Fetching match: NA1_4603289825
# Fetching match: VN2_50881518
# Fetching match: EUW1_6313728822
# Fetching match: BR1_2696662185
# Fetching match: LA1_1365244238
# Fetching match: PH2_8376694
# Fetching match: BR1_2698008307
# Fetching match: VN2_53606096
# Fetching match: EUN1_3337520822
# Fetching match: LA2_1279650368
# Fetching match: VN2_53769863
# Fetching match: VN2_50211368
# Fetching match: LA1_1366009497
# Fetching match: OC1_562991074
# Fetching match: TR1_1392090908
# Fetching match: VN2_53918548
# Fetching match: LA2_1279395633
# Fetching match: BR1_2696635208
# Fetching match: LA2_1279806133
# Fetching match: TW2_48727148
# Fetching match: JP1_390115701
# Fetching match: BR1_2696745636
# Fetching match: KR_6418246212
# Fetching match: KR_6415918568
# Fetching match: TW2_47973871
# Fetching match: EUN1_3335186600
# Fetching match: SG2_4511985
# Fetching match: NA1_4606585453
# Fetching match: VN2_50770520
# Fetching match: BR1_2692465381
# Fetching match: EUN1_3331130931
# Fetching match: LA1_1368973631
# Fetching match: PH2_8440596
# Fetching match: EUW1_6299943288
# Fetching match: KR_6414279110
# Fetching match: VN2_51656360
# Fetching match: TR1_1391862920
# Fetching match: NA1_4607201016
# Fetching match: EUN1_3337633917
# Fetching match: PH2_7710123
# Fetching match: TR1_1387141995
# Fetching match: NA1_4599874350
# Fetching match: TR1_1392049329
# Fetching match: LA2_1279790428
# Fetching match: NA1_4605730563
# Fetching match: EUN1_3338656799
# Fetching match: LA1_1369197600
# Fetching match: PH2_8347060
# Fetching match: PH2_8449176
# Fetching match: BR1_2701376484
# Fetching match: KR_6412222125
# Fetching match: EUN1_3332704637
# Fetching match: VN2_54189790
# Fetching match: LA1_1369564796
# Fetching match: TW2_47873883
# Fetching match: NA1_4601478600
# Fetching match: TW2_46070054
# Fetching match: PH2_7731875
# Fetching match: LA2_1280079928
# Fetching match: NA1_4601143383
# Fetching match: EUN1_3334941154
# Fetching match: NA1_4605056760
# Fetching match: BR1_2698752754
# Fetching match: JP1_390955542
# Fetching match: EUW1_6328197782
# Fetching match: KR_6409737107
# Fetching match: RU_434923765
# Fetching match: NA1_4608155244
# Fetching match: TH2_3573415
# Fetching match: BR1_2698574589
# Fetching match: VN2_49395908
# Fetching match: EUN1_3335230801
# Fetching match: LA1_1368298459
# Fetching match: LA2_1280357743
# Fetching match: BR1_2701285390
# Fetching match: NA1_4610145859
# Fetching match: TW2_48966908
# Fetching match: LA2_1279593849
# Fetching match: LA1_1368736997
# Fetching match: PH2_8471135
# Fetching match: EUN1_3333406382
# Fetching match: LA2_1280577780
# Fetching match: LA2_1280814375
# Fetching match: KR_6417887565
# Fetching match: PH2_8122235
# Fetching match: LA1_1369247473
# Fetching match: NA1_4607052670
# Fetching match: TW2_48821483
# Fetching match: TR1_1390312670
# Fetching match: EUN1_3337698783
# Fetching match: NA1_4607876372
# Fetching match: EUN1_3334473890
# Fetching match: LA1_1366056901
# Fetching match: LA1_1363954693
# Fetching match: TW2_46226733
# Fetching match: EUW1_6311057222
# Fetching match: TH2_3214146
# Fetching match: PH2_8326701
# Fetching match: EUW1_6327354499
# Fetching match: EUW1_6311763860
# Fetching match: BR1_2701278657
# Fetching match: VN2_52876619
# Fetching match: RU_432139499
# Fetching match: EUW1_6312340154
# Fetching match: BR1_2700480838
# Fetching match: VN2_44144442
# Fetching match: VN2_52518502
# Fetching match: NA1_4604069604
# Fetching match: NA1_4604449454
# Fetching match: KR_6404856675
# Fetching match: OC1_562914933
# Fetching match: TR1_1392021234
# Fetching match: EUW1_6321483095
# Fetching match: LA1_1369415744
# Fetching match: LA1_1368642065
# Fetching match: JP1_390267190
# Fetching match: EUW1_6328085408
# Fetching match: EUW1_6327949966
# Fetching match: NA1_4609637976
# Fetching match: KR_6416194422
# Fetching match: EUN1_3336543743
# Fetching match: EUN1_3334596711
# Fetching match: VN2_53468546
# Fetching match: LA1_1369422064
# Fetching match: EUN1_3337921423
# Fetching match: LA1_1369026811
# Fetching match: PH2_7361028
# Fetching match: EUN1_3337250202
# Fetching match: OC1_562672199
# Fetching match: NA1_4602809065
# Fetching match: KR_6419285119
# Fetching match: KR_6416327711
# Fetching match: VN2_51224714
# Fetching match: BR1_2699380998
# Fetching match: LA2_1280506447
# Fetching match: BR1_2699454602
# Fetching match: PH2_7424401
# Fetching match: LA1_1365563729
# Fetching match: OC1_563424546
# Fetching match: EUW1_6326931858
# Fetching match: NA1_4606435754
# Fetching match: EUW1_6316617443
# Fetching match: LA1_1369057643
# Fetching match: TW2_48853770
# Fetching match: TW2_44653183
# Fetching match: LA1_1367832756
# Fetching match: TW2_47951072
# Fetching match: VN2_48041133
# Fetching match: VN2_50098502
# Fetching match: LA1_1368549056
# ...
# No longer Rate limited count: 73
# Took 0:54:03.121146 to complete 25773 requests on https://americas.api.riotgames.com/lol/match/v5/matches/NA1_4607710072 and API token RGAPI-d93ad850-d1e8-404a-a9f7-db6ba9a6016b
# No longer Rate limited count: 72
# Took 0:54:03.199875 to complete 25774 requests on https://americas.api.riotgames.com/lol/match/v5/matches/NA1_4608745863 and API token RGAPI-d93ad850-d1e8-404a-a9f7-db6ba9a6016b
# Rate limited, retrying after 109 seconds.
# Rate limited count: 73
# No longer Rate limited count: 72
# Took 0:54:03.200724 to complete 25775 requests on https://americas.api.riotgames.com/lol/match/v5/matches/LA1_1369229608 and API token RGAPI-d93ad850-d1e8-404a-a9f7-db6ba9a6016b
# No longer Rate limited count: 71
# Took 0:54:03.476243 to complete 25776 requests on https://americas.api.riotgames.com/lol/match/v5/matches/LA2_1279217946 and API token RGAPI-d93ad850-d1e8-404a-a9f7-db6ba9a6016b
# No longer Rate limited count: 70
# Took 0:54:03.482243 to complete 25777 requests on https://americas.api.riotgames.com/lol/match/v5/matches/LA1_1369689057 and API token RGAPI-d93ad850-d1e8-404a-a9f7-db6ba9a6016b
# Rate limited, retrying after 108 seconds.
# Rate limited count: 71
# No longer Rate limited count: 70
# Took 0:54:03.482243 to complete 25778 requests on https://americas.api.riotgames.com/lol/match/v5/matches/LA2_1280049998 and API token RGAPI-d93ad850-d1e8-404a-a9f7-db6ba9a6016b
# No longer Rate limited count: 69
# Took 0:54:03.484265 to complete 25779 requests on https://americas.api.riotgames.com/lol/match/v5/matches/LA1_1368298459 and API token RGAPI-d93ad850-d1e8-404a-a9f7-db6ba9a6016b
# Rate limited, retrying after 108 seconds.
# Rate limited count: 70
# No longer Rate limited count: 69
# Took 0:54:03.485264 to complete 25780 requests on https://americas.api.riotgames.com/lol/match/v5/matches/NA1_4608065008 and API token RGAPI-d93ad850-d1e8-404a-a9f7-db6ba9a6016b
# No longer Rate limited count: 68
# Took 0:54:03.487253 to complete 25781 requests on https://americas.api.riotgames.com/lol/match/v5/matches/LA1_1369474227 and API token RGAPI-d93ad850-d1e8-404a-a9f7-db6ba9a6016b
# No longer Rate limited count: 67
# Took 0:54:03.489242 to complete 25782 requests on https://americas.api.riotgames.com/lol/match/v5/matches/LA2_1280337516 and API token RGAPI-d93ad850-d1e8-404a-a9f7-db6ba9a6016b
# Rate limited, retrying after 108 seconds.
# Rate limited count: 68
# No longer Rate limited count: 67
# Took 0:54:03.489242 to complete 25783 requests on https://americas.api.riotgames.com/lol/match/v5/matches/LA1_1369812985 and API token RGAPI-d93ad850-d1e8-404a-a9f7-db6ba9a6016b
# No longer Rate limited count: 66
# Took 0:54:03.491249 to complete 25784 requests on https://americas.api.riotgames.com/lol/match/v5/matches/NA1_4607192367 and API token RGAPI-d93ad850-d1e8-404a-a9f7-db6ba9a6016b
# No longer Rate limited count: 65
# Took 0:54:03.573988 to complete 25785 requests on https://americas.api.riotgames.com/lol/match/v5/matches/LA1_1368905201 and API token RGAPI-d93ad850-d1e8-404a-a9f7-db6ba9a6016b
# No longer Rate limited count: 64
# Took 0:54:03.689653 to complete 25786 requests on https://americas.api.riotgames.com/lol/match/v5/matches/BR1_2700831775 and API token RGAPI-d93ad850-d1e8-404a-a9f7-db6ba9a6016b
# No longer Rate limited count: 63
# Took 0:54:03.722668 to complete 25787 requests on https://americas.api.riotgames.com/lol/match/v5/matches/BR1_2700424061 and API token RGAPI-d93ad850-d1e8-404a-a9f7-db6ba9a6016b
# No longer Rate limited count: 62
# Took 0:54:03.772593 to complete 25788 requests on https://americas.api.riotgames.com/lol/match/v5/matches/NA1_4602055827 and API token RGAPI-d93ad850-d1e8-404a-a9f7-db6ba9a6016b
# No longer Rate limited count: 61
# Took 0:54:03.804004 to complete 25789 requests on https://americas.api.riotgames.com/lol/match/v5/matches/BR1_2695362502 and API token RGAPI-d93ad850-d1e8-404a-a9f7-db6ba9a6016b
# No longer Rate limited count: 60
# Took 0:54:04.042000 to complete 25790 requests on https://americas.api.riotgames.com/lol/match/v5/matches/NA1_4605218398 and API token RGAPI-d93ad850-d1e8-404a-a9f7-db6ba9a6016b
# No longer Rate limited count: 59
# Took 0:54:04.541685 to complete 25791 requests on https://sea.api.riotgames.com/lol/match/v5/matches/TW2_41740630 and API token RGAPI-38d5ab33-910b-492e-ac00-bb5f086e03e8
# No longer Rate limited count: 58
# Took 0:54:04.687125 to complete 25792 requests on https://americas.api.riotgames.com/lol/match/v5/matches/LA2_1279859097 and API token RGAPI-d93ad850-d1e8-404a-a9f7-db6ba9a6016b
# No longer Rate limited count: 57
# Took 0:54:05.196952 to complete 25793 requests on https://americas.api.riotgames.com/lol/match/v5/matches/LA1_1369674726 and API token RGAPI-d93ad850-d1e8-404a-a9f7-db6ba9a6016b
# No longer Rate limited count: 56
# Took 0:54:05.248580 to complete 25794 requests on https://americas.api.riotgames.com/lol/match/v5/matches/LA1_1369178313 and API token RGAPI-d93ad850-d1e8-404a-a9f7-db6ba9a6016b
# No longer Rate limited count: 55
# Took 0:54:05.250586 to complete 25795 requests on https://americas.api.riotgames.com/lol/match/v5/matches/NA1_4609975592 and API token RGAPI-d93ad850-d1e8-404a-a9f7-db6ba9a6016b
# No longer Rate limited count: 54
# Took 0:54:05.284794 to complete 25796 requests on https://americas.api.riotgames.com/lol/match/v5/matches/LA1_1369447211 and API token RGAPI-d93ad850-d1e8-404a-a9f7-db6ba9a6016b
# No longer Rate limited count: 53
# Took 0:54:05.360534 to complete 25797 requests on https://americas.api.riotgames.com/lol/match/v5/matches/LA1_1367694803 and API token RGAPI-d93ad850-d1e8-404a-a9f7-db6ba9a6016b
# No longer Rate limited count: 52
# Took 0:54:05.419710 to complete 25798 requests on https://americas.api.riotgames.com/lol/match/v5/matches/NA1_4596696598 and API token RGAPI-d93ad850-d1e8-404a-a9f7-db6ba9a6016b
# Rate limited, retrying after 106 seconds.
# Rate limited count: 53
# No longer Rate limited count: 52
# Took 0:54:05.421750 to complete 25799 requests on https://americas.api.riotgames.com/lol/match/v5/matches/LA2_1278527646 and API token RGAPI-d93ad850-d1e8-404a-a9f7-db6ba9a6016b
# No longer Rate limited count: 51
# Took 0:54:05.597182 to complete 25800 requests on https://americas.api.riotgames.com/lol/match/v5/matches/NA1_4606684267 and API token RGAPI-d93ad850-d1e8-404a-a9f7-db6ba9a6016b
# No longer Rate limited count: 50
# Took 0:54:05.699855 to complete 25801 requests on https://americas.api.riotgames.com/lol/match/v5/matches/LA2_1280691276 and API token RGAPI-d93ad850-d1e8-404a-a9f7-db6ba9a6016b
# No longer Rate limited count: 49
# Took 0:54:05.991463 to complete 25802 requests on https://americas.api.riotgames.com/lol/match/v5/matches/LA2_1279864209 and API token RGAPI-d93ad850-d1e8-404a-a9f7-db6ba9a6016b
# No longer Rate limited count: 48
# Took 0:54:06.124600 to complete 25803 requests on https://americas.api.riotgames.com/lol/match/v5/matches/LA2_1278304214 and API token RGAPI-d93ad850-d1e8-404a-a9f7-db6ba9a6016b
# Rate limited, retrying after 106 seconds.
# Rate limited count: 49
# No longer Rate limited count: 48
# Took 0:54:06.255089 to complete 25804 requests on https://americas.api.riotgames.com/lol/match/v5/matches/BR1_2698209124 and API token RGAPI-d93ad850-d1e8-404a-a9f7-db6ba9a6016b
# Rate limited, retrying after 106 seconds.
# Rate limited count: 49
# No longer Rate limited count: 48
# Took 0:54:06.519442 to complete 25805 requests on https://americas.api.riotgames.com/lol/match/v5/matches/LA1_1369552335 and API token RGAPI-d93ad850-d1e8-404a-a9f7-db6ba9a6016b
# Rate limited, retrying after 105 seconds.
# Rate limited count: 49
# No longer Rate limited count: 48
# Took 0:54:16.417501 to complete 25806 requests on https://americas.api.riotgames.com/lol/match/v5/matches/LA1_1368653321 and API token RGAPI-d93ad850-d1e8-404a-a9f7-db6ba9a6016b
# Rate limited, retrying after 95 seconds.
# Rate limited count: 49
# No longer Rate limited count: 48
# Took 0:54:38.110166 to complete 25807 requests on https://sea.api.riotgames.com/lol/match/v5/matches/TW2_48777184 and API token RGAPI-58b977e3-1fe9-4eef-a1b9-8cf817e627fa
# No longer Rate limited count: 47
# Took 0:54:44.126337 to complete 25808 requests on https://americas.api.riotgames.com/lol/match/v5/matches/LA2_1280500718 and API token RGAPI-121a01ec-58ea-4094-8d7e-9f613f88cbf3
# No longer Rate limited count: 46
# Took 0:54:44.245778 to complete 25809 requests on https://americas.api.riotgames.com/lol/match/v5/matches/LA2_1280052982 and API token RGAPI-121a01ec-58ea-4094-8d7e-9f613f88cbf3
# No longer Rate limited count: 45
# Took 0:54:44.264468 to complete 25810 requests on https://americas.api.riotgames.com/lol/match/v5/matches/LA1_1369270936 and API token RGAPI-121a01ec-58ea-4094-8d7e-9f613f88cbf3
# No longer Rate limited count: 44
# Took 0:54:44.290139 to complete 25811 requests on https://americas.api.riotgames.com/lol/match/v5/matches/LA1_1368525790 and API token RGAPI-121a01ec-58ea-4094-8d7e-9f613f88cbf3
# No longer Rate limited count: 43
# Took 0:54:44.408754 to complete 25812 requests on https://americas.api.riotgames.com/lol/match/v5/matches/NA1_4609777684 and API token RGAPI-58b977e3-1fe9-4eef-a1b9-8cf817e627fa
# No longer Rate limited count: 42
# Took 0:54:44.464786 to complete 25813 requests on https://americas.api.riotgames.com/lol/match/v5/matches/LA1_1368556230 and API token RGAPI-58b977e3-1fe9-4eef-a1b9-8cf817e627fa
# No longer Rate limited count: 41
# Took 0:54:44.465785 to complete 25814 requests on https://americas.api.riotgames.com/lol/match/v5/matches/NA1_4607874054 and API token RGAPI-121a01ec-58ea-4094-8d7e-9f613f88cbf3
# No longer Rate limited count: 40
# Took 0:54:44.484792 to complete 25815 requests on https://americas.api.riotgames.com/lol/match/v5/matches/LA2_1279893274 and API token RGAPI-121a01ec-58ea-4094-8d7e-9f613f88cbf3
# No longer Rate limited count: 39
# Took 0:54:44.651064 to complete 25816 requests on https://americas.api.riotgames.com/lol/match/v5/matches/LA1_1369492884 and API token RGAPI-121a01ec-58ea-4094-8d7e-9f613f88cbf3
# No longer Rate limited count: 38
# Took 0:54:44.858710 to complete 25817 requests on https://americas.api.riotgames.com/lol/match/v5/matches/LA2_1279175806 and API token RGAPI-121a01ec-58ea-4094-8d7e-9f613f88cbf3
# No longer Rate limited count: 37
# Took 0:54:45.046445 to complete 25818 requests on https://americas.api.riotgames.com/lol/match/v5/matches/NA1_4609266906 and API token RGAPI-121a01ec-58ea-4094-8d7e-9f613f88cbf3
# No longer Rate limited count: 36
# Took 0:54:45.099699 to complete 25819 requests on https://americas.api.riotgames.com/lol/match/v5/matches/LA1_1368497195 and API token RGAPI-121a01ec-58ea-4094-8d7e-9f613f88cbf3
# No longer Rate limited count: 35
# Took 0:54:45.110114 to complete 25820 requests on https://americas.api.riotgames.com/lol/match/v5/matches/LA2_1279766746 and API token RGAPI-58b977e3-1fe9-4eef-a1b9-8cf817e627fa
# No longer Rate limited count: 34
# Took 0:54:45.113056 to complete 25821 requests on https://americas.api.riotgames.com/lol/match/v5/matches/LA2_1279581698 and API token RGAPI-38d5ab33-910b-492e-ac00-bb5f086e03e8
# No longer Rate limited count: 33
# Took 0:54:45.164057 to complete 25822 requests on https://americas.api.riotgames.com/lol/match/v5/matches/NA1_4608540173 and API token RGAPI-58b977e3-1fe9-4eef-a1b9-8cf817e627fa
# No longer Rate limited count: 32
# Took 0:54:45.244487 to complete 25823 requests on https://americas.api.riotgames.com/lol/match/v5/matches/BR1_2700113388 and API token RGAPI-58b977e3-1fe9-4eef-a1b9-8cf817e627fa
# No longer Rate limited count: 31
# Took 0:54:45.298205 to complete 25824 requests on https://americas.api.riotgames.com/lol/match/v5/matches/BR1_2694984604 and API token RGAPI-da3e753f-9145-4edc-8be5-54dce7e81e5c
# No longer Rate limited count: 30
# Took 0:54:45.311219 to complete 25825 requests on https://americas.api.riotgames.com/lol/match/v5/matches/NA1_4608300557 and API token RGAPI-da3e753f-9145-4edc-8be5-54dce7e81e5c
# No longer Rate limited count: 29
# Took 0:54:45.313223 to complete 25826 requests on https://americas.api.riotgames.com/lol/match/v5/matches/LA1_1369606375 and API token RGAPI-da3e753f-9145-4edc-8be5-54dce7e81e5c
# No longer Rate limited count: 28
# Took 0:54:45.316222 to complete 25827 requests on https://americas.api.riotgames.com/lol/match/v5/matches/NA1_4608494019 and API token RGAPI-da3e753f-9145-4edc-8be5-54dce7e81e5c
# No longer Rate limited count: 27
# Took 0:54:45.416178 to complete 25828 requests on https://americas.api.riotgames.com/lol/match/v5/matches/LA1_1369483288 and API token RGAPI-da3e753f-9145-4edc-8be5-54dce7e81e5c
# No longer Rate limited count: 26
# Took 0:54:45.421980 to complete 25829 requests on https://americas.api.riotgames.com/lol/match/v5/matches/LA1_1368186495 and API token RGAPI-38d5ab33-910b-492e-ac00-bb5f086e03e8
# No longer Rate limited count: 25
# Took 0:54:45.487751 to complete 25830 requests on https://americas.api.riotgames.com/lol/match/v5/matches/LA1_1368210966 and API token RGAPI-da3e753f-9145-4edc-8be5-54dce7e81e5c
# No longer Rate limited count: 24
# Took 0:54:45.546519 to complete 25831 requests on https://americas.api.riotgames.com/lol/match/v5/matches/NA1_4605914147 and API token RGAPI-38d5ab33-910b-492e-ac00-bb5f086e03e8
# No longer Rate limited count: 23
# Took 0:54:45.620535 to complete 25832 requests on https://americas.api.riotgames.com/lol/match/v5/matches/NA1_4606871231 and API token RGAPI-38d5ab33-910b-492e-ac00-bb5f086e03e8
# No longer Rate limited count: 22
# Took 0:54:46.297150 to complete 25833 requests on https://americas.api.riotgames.com/lol/match/v5/matches/BR1_2700722520 and API token RGAPI-da3e753f-9145-4edc-8be5-54dce7e81e5c
# No longer Rate limited count: 21
# Took 0:54:47.222863 to complete 25834 requests on https://americas.api.riotgames.com/lol/match/v5/matches/LA2_1279548649 and API token RGAPI-38d5ab33-910b-492e-ac00-bb5f086e03e8
# No longer Rate limited count: 20
# Took 0:55:53.574933 to complete 25835 requests on https://americas.api.riotgames.com/lol/match/v5/matches/LA1_1369689057 and API token RGAPI-d93ad850-d1e8-404a-a9f7-db6ba9a6016b
# No longer Rate limited count: 19
# Took 0:55:53.576927 to complete 25836 requests on https://americas.api.riotgames.com/lol/match/v5/matches/LA2_1280337516 and API token RGAPI-d93ad850-d1e8-404a-a9f7-db6ba9a6016b
# No longer Rate limited count: 18
# Took 0:55:53.578889 to complete 25837 requests on https://americas.api.riotgames.com/lol/match/v5/matches/LA1_1368653321 and API token RGAPI-d93ad850-d1e8-404a-a9f7-db6ba9a6016b
# No longer Rate limited count: 17
# Took 0:55:53.582873 to complete 25838 requests on https://americas.api.riotgames.com/lol/match/v5/matches/LA1_1369552335 and API token RGAPI-d93ad850-d1e8-404a-a9f7-db6ba9a6016b
# No longer Rate limited count: 16
# Took 0:55:53.587873 to complete 25839 requests on https://americas.api.riotgames.com/lol/match/v5/matches/LA1_1368298459 and API token RGAPI-d93ad850-d1e8-404a-a9f7-db6ba9a6016b
# No longer Rate limited count: 15
# Took 0:55:53.715168 to complete 25840 requests on https://americas.api.riotgames.com/lol/match/v5/matches/NA1_4596696598 and API token RGAPI-d93ad850-d1e8-404a-a9f7-db6ba9a6016b
# No longer Rate limited count: 14
# Took 0:55:53.785912 to complete 25841 requests on https://americas.api.riotgames.com/lol/match/v5/matches/LA2_1278304214 and API token RGAPI-d93ad850-d1e8-404a-a9f7-db6ba9a6016b
# No longer Rate limited count: 13
# Took 0:55:53.789080 to complete 25842 requests on https://americas.api.riotgames.com/lol/match/v5/matches/NA1_4608745863 and API token RGAPI-d93ad850-d1e8-404a-a9f7-db6ba9a6016b
# No longer Rate limited count: 12
# Took 0:55:53.827238 to complete 25843 requests on https://americas.api.riotgames.com/lol/match/v5/matches/LA2_1280445408 and API token RGAPI-d93ad850-d1e8-404a-a9f7-db6ba9a6016b
# No longer Rate limited count: 11
# Took 0:55:53.830125 to complete 25844 requests on https://americas.api.riotgames.com/lol/match/v5/matches/LA2_1280429023 and API token RGAPI-d93ad850-d1e8-404a-a9f7-db6ba9a6016b
# No longer Rate limited count: 10
# Took 0:55:53.832132 to complete 25845 requests on https://americas.api.riotgames.com/lol/match/v5/matches/BR1_2698209124 and API token RGAPI-d93ad850-d1e8-404a-a9f7-db6ba9a6016b

# %% [markdown]
# ### Match Details

# %%
# @task(task_id="match_general_info")
def get_match_general_info(raw_match: dict) -> dict:
    match = {}

    match['matchId'] = raw_match['metadata']['matchId']
    keys_to_exlude = {
        "participants",
        "teams",
    }
    match |= { key:raw_match["metadata"][key] for key in set(set(raw_match["metadata"].keys()) - keys_to_exlude)}
    match |= { key:raw_match["info"][key] for key in set(set(raw_match["info"].keys()) - keys_to_exlude)}
    return match

# @task(task_id = "match_players_info")
def get_match_players_info(raw_match: dict) -> list[dict]:
    if raw_match is None:
        print("Match none detected")
        return {}
    
    keys_initial_exclude = {
        "challenges",
        "perks",
    }

    raw_participants_details  : list[dict] = raw_match["info"]["participants"]

    final_participants_details : list[dict] = []
    
    for raw_participant in raw_participants_details:
        participant = {}
        
        #Normal Keys
        participant |= { key:raw_participant[key] for key in set(set(raw_participant.keys()) - keys_initial_exclude)}

        #Challenges DTO flattened
        if "challenges" in raw_participant.keys():
            participant |= { f"challenges_{key}":raw_participant["challenges"][key] for key in raw_participant["challenges"].keys()}

        #Runes DTO stat perks flattened
        participant |= { f"statPerks_{key}": raw_participant["perks"]["statPerks"][key] for key in raw_participant["perks"]["statPerks"].keys() }
        
        #Runes DTO styles flattened
        for style in raw_participant["perks"]["styles"]:
            temp = {}

            style_type = style['description']
            temp[f"{ style_type }_id"] = style["style"]
            
            #PerkStyleSelectionDto
            for index, perk in enumerate(style["selections"]):
                temp[f"{style_type}_{index}_id"] = perk["perk"]
                temp[f"{style_type}_{index}_var1"] = perk["var1"]
                temp[f"{style_type}_{index}_var2"] = perk["var2"]
                temp[f"{style_type}_{index}_var3"] = perk["var3"]
            
            participant |= temp

        final_participants_details.append(participant)
    
    return final_participants_details

def get_match_teams_info(raw_match: dict) -> dict:
    teams_info_raw = raw_match["info"]["teams"]
    teams_info = {}

    teams_info["matchId"] = raw_match["metadata"]["matchId"]
    for team in teams_info_raw:
        team_name = "blue" if team["teamId"] == 100 else "red"
        for bans in team["bans"]:
            teams_info[f"bans_turn_{bans['pickTurn']}"] = bans["championId"]
        for objective in team["objectives"].keys():
            teams_info[f"{team_name}_{objective}_isFirstKill"] = team["objectives"][objective]["first"]
            teams_info[f"{team_name}_{objective}_kills"] = team["objectives"][objective]["kills"]
        teams_info[f"{team_name}_win"] = team["win"]
    return teams_info

# %%
match_general_info = pd.DataFrame([get_match_general_info(match) for match in raw_match_history_details])
display(match_general_info)

match_player_info = itertools.chain.from_iterable([get_match_players_info(match) for match in raw_match_history_details])
match_player_info = pd.DataFrame(match_player_info)
display(match_player_info)

match_teams_info = pd.DataFrame([get_match_teams_info(match) for match in raw_match_history_details])
display(match_teams_info)
# Out:
#               matchId dataVersion   gameCreation  mapId  queueId  \
# 0        RU_435038708           2  1679584376474     11      400
# 1      NA1_4602846851           2  1678945422148     11      420
# 2      LA2_1280731187           2  1679609367071     11      420
# 3      LA2_1278214825           2  1678899109847     11      420
# 4     EUW1_6328908072           2  1679614505176     12      450
# ...               ...         ...            ...    ...      ...
# 2994   NA1_4609777684           2  1679627296862     12      450
# 2995     TW2_46472377           2  1679123482156     12      450
# 2996  EUN1_3334925679           2  1679096478343     11      440
# 2997   LA1_1368556230           2  1679333125979     11      420
# 2998      PH2_8502880           2  1679643614886     11      430
#
#       gameEndTimestamp gameMode tournamentCode      gameType  gameDuration  \
# 0        1679586359484  CLASSIC                 MATCHED_GAME          1913
# 1        1678946408901  CLASSIC                 MATCHED_GAME           967
# 2        1679611060907  CLASSIC                 MATCHED_GAME          1622
# 3        1678901093213  CLASSIC                 MATCHED_GAME          1953
# 4        1679616162245     ARAM                 MATCHED_GAME          1565
# ...                ...      ...            ...           ...           ...
# 2994     1679628089137     ARAM                 MATCHED_GAME           740
# 2995     1679125042387     ARAM                 MATCHED_GAME          1512
# 2996     1679098239638  CLASSIC                 MATCHED_GAME          1651
# 2997     1679335305119  CLASSIC                 MATCHED_GAME          2142
# 2998     1679646552263  CLASSIC                 MATCHED_GAME          2857
#
#           gameId    gameVersion  gameStartTimestamp platformId  \
# 0      435038708   13.6.499.913       1679584446394         RU
# 1     4602846851  13.5.495.8836       1678945441738        NA1
# 2     1280731187   13.6.499.913       1679609438176        LA2
# 3     1278214825  13.5.495.8836       1678899139180        LA2
# 4     6328908072   13.6.499.913       1679614596445       EUW1
# ...          ...            ...                 ...        ...
# 2994  4609777684  13.6.499.7165       1679627348897        NA1
# 2995    46472377  13.5.495.8836       1679123530393        TW2
# 2996  3334925679  13.5.495.8836       1679096588234       EUN1
# 2997  1368556230  13.5.495.8836       1679333162743        LA1
# 2998     8502880  13.6.499.7165       1679643695124        PH2
#
#                           gameName
# 0      teambuilder-match-435038708
# 1     teambuilder-match-4602846851
# 2     teambuilder-match-1280731187
# 3     teambuilder-match-1278214825
# 4     teambuilder-match-6328908072
# ...                            ...
# 2994  teambuilder-match-4609777684
# 2995    teambuilder-match-46472377
# 2996  teambuilder-match-3334925679
# 2997  teambuilder-match-1368556230
# 2998     teambuilder-match-8502880
#
# [2999 rows x 15 columns]
#        inhibitorTakedowns  nexusLost  totalDamageTaken  firstBloodAssist  \
# 0                       0          1             26106             False
# 1                       0          1             42981             False
# 2                       0          1             36150              True
# 3                       0          1             28864             False
# 4                       0          1             24569             False
# ...                   ...        ...               ...               ...
# 29961                   1          0             37032             False
# 29962                   0          0             49686             False
# 29963                   1          0             91610             False
# 29964                   0          0             79597             False
# 29965                   0          0             35944             False
#
#        trueDamageDealt riotIdTagline  turretTakedowns  enemyMissingPings  \
# 0                 3284                              0                  3
# 1                33156                              0                  1
# 2                13849                              2                  6
# 3                37985                              0                  7
# 4                  994                              1                  0
# ...                ...           ...              ...                ...
# 29961             6676                              6                  2
# 29962             4245                              4                  9
# 29963           106858                              5                  3
# 29964            59228                              1                 16
# 29965              455                              5                  3
#
#        damageDealtToObjectives  profileIcon  ...  \
# 0                         7494           24  ...
# 1                        17259         3778  ...
# 2                        17897         3838  ...
# 3                         1046         5182  ...
# 4                          517         3836  ...
# ...                        ...          ...  ...
# 29961                    10344         4793  ...
# 29962                     5544         4405  ...
# 29963                    23393         5681  ...
# 29964                    53644         3633  ...
# 29965                     4690         5753  ...
#
#        challenges_firstTurretKilledTime  challenges_highestCrowdControlScore  \
# 0                                   NaN                                  NaN
# 1                                   NaN                                  NaN
# 2                                   NaN                                  NaN
# 3                                   NaN                                  NaN
# 4                                   NaN                                  NaN
# ...                                 ...                                  ...
# 29961                        988.011877                                  NaN
# 29962                        988.011877                                  NaN
# 29963                        988.011877                                  NaN
# 29964                        988.011877                                  NaN
# 29965                        988.011877                                  NaN
#
#        challenges_thirdInhibitorDestroyedTime  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
# ...                                       ...
# 29961                                     NaN
# 29962                                     NaN
# 29963                                     NaN
# 29964                                     NaN
# 29965                                     NaN
#
#        challenges_shortestTimeToAceFromFirstTakedown  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# ...                                              ...
# 29961                                            NaN
# 29962                                            NaN
# 29963                                            NaN
# 29964                                            NaN
# 29965                                            NaN
#
#        challenges_fasterSupportQuestCompletion  challenges_highestWardKills  \
# 0                                          NaN                          NaN
# 1                                          NaN                          NaN
# 2                                          NaN                          NaN
# 3                                          NaN                          NaN
# 4                                          NaN                          NaN
# ...                                        ...                          ...
# 29961                                      NaN                          NaN
# 29962                                      NaN                          NaN
# 29963                                      NaN                          NaN
# 29964                                      NaN                          NaN
# 29965                                      NaN                          NaN
#
#        challenges_baronBuffGoldAdvantageOverThreshold  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ...                                               ...
# 29961                                             NaN
# 29962                                             NaN
# 29963                                             NaN
# 29964                                             NaN
# 29965                                             NaN
#
#        challenges_hadAfkTeammate  challenges_teleportTakedowns  \
# 0                            NaN                           NaN
# 1                            NaN                           NaN
# 2                            NaN                           NaN
# 3                            NaN                           NaN
# 4                            NaN                           NaN
# ...                          ...                           ...
# 29961                        NaN                           NaN
# 29962                        NaN                           NaN
# 29963                        NaN                           NaN
# 29964                        NaN                           NaN
# 29965                        NaN                           NaN
#
#       challenges_mejaisFullStackInTime
# 0                                  NaN
# 1                                  NaN
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN
# ...                                ...
# 29961                              NaN
# 29962                              NaN
# 29963                              NaN
# 29964                              NaN
# 29965                              NaN
#
# [29966 rows x 276 columns]
#               matchId  bans_turn_1  bans_turn_2  bans_turn_3  bans_turn_4  \
# 0        RU_435038708        136.0        238.0         25.0          8.0
# 1      NA1_4602846851        350.0        119.0        497.0        412.0
# 2      LA2_1280731187         38.0         64.0        119.0         58.0
# 3      LA2_1278214825        221.0        887.0         24.0        350.0
# 4     EUW1_6328908072          NaN          NaN          NaN          NaN
# ...               ...          ...          ...          ...          ...
# 2994   NA1_4609777684          NaN          NaN          NaN          NaN
# 2995     TW2_46472377          NaN          NaN          NaN          NaN
# 2996  EUN1_3334925679        498.0        106.0        202.0        420.0
# 2997   LA1_1368556230         25.0        117.0        157.0        136.0
# 2998      PH2_8502880          NaN          NaN          NaN          NaN
#
#       bans_turn_5  blue_baron_isFirstKill  blue_baron_kills  \
# 0           119.0                    True                 1
# 1            29.0                   False                 0
# 2            59.0                   False                 0
# 3           134.0                    True                 1
# 4             NaN                   False                 0
# ...           ...                     ...               ...
# 2994          NaN                   False                 0
# 2995          NaN                   False                 0
# 2996          7.0                   False                 0
# 2997         77.0                    True                 1
# 2998          NaN                   False                 0
#
#       blue_champion_isFirstKill  blue_champion_kills  ...  red_champion_kills  \
# 0                          True                   36  ...                  42
# 1                          True                   31  ...                   7
# 2                          True                   29  ...                  43
# 3                          True                   34  ...                  20
# 4                         False                   73  ...                  81
# ...                         ...                  ...  ...                 ...
# 2994                       True                   39  ...                  30
# 2995                      False                   93  ...                  76
# 2996                      False                   30  ...                  38
# 2997                      False                   36  ...                  50
# 2998                       True                   54  ...                  47
#
#       red_dragon_isFirstKill  red_dragon_kills  red_inhibitor_isFirstKill  \
# 0                       True                 5                       True
# 1                      False                 0                      False
# 2                      False                 2                       True
# 3                      False                 1                      False
# 4                      False                 0                       True
# ...                      ...               ...                        ...
# 2994                   False                 0                      False
# 2995                   False                 0                       True
# 2996                    True                 2                       True
# 2997                    True                 4                      False
# 2998                    True                 5                      False
#
#       red_inhibitor_kills  red_riftHerald_isFirstKill  red_riftHerald_kills  \
# 0                       3                       False                     1
# 1                       0                       False                     0
# 2                       1                        True                     2
# 3                       0                        True                     1
# 4                       2                       False                     0
# ...                   ...                         ...                   ...
# 2994                    0                       False                     0
# 2995                    1                       False                     0
# 2996                    3                        True                     2
# 2997                    2                        True                     2
# 2998                    1                        True                     1
#
#       red_tower_isFirstKill  red_tower_kills  red_win
# 0                      True               11     True
# 1                     False                1    False
# 2                      True                8     True
# 3                      True                5    False
# 4                      True                4     True
# ...                     ...              ...      ...
# 2994                  False                0    False
# 2995                   True                4    False
# 2996                   True                9     True
# 2997                   True               11     True
# 2998                   True                8     True
#
# [2999 rows x 37 columns]
